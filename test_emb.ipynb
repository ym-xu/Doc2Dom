# %%
import sys
import os
import pickle
from dataclasses import dataclass, asdict
import json
import numpy as np
from typing import Dict, List, Any, Optional, Tuple
import logging
from pathlib import Path
from tqdm import tqdm
import hashlib
# sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("/Users/ymxu/Workspace/MuDocU/DOMAGENT/tests/test_subtree_emb.py"))))
from subtree_embedding import SubtreeEmbedder
# from src.core.dom_processor_v2 import TokenAwareDOMProcessor, DOMNode
from json_to_dom_processor import DOMNode
@dataclass
class EmbeddingResult:
    node_id: str
    embedding: np.ndarray
    metadata: Dict[str, Any]
    structure_info: Dict[str, Any]
    parent_id: Optional[str] = None
    children_ids: List[str] = None
    embedding_time: float = 0.0
# Out:
# Qwen2VL not available. Please install transformers and torch to use Qwen2VL.

# %%
config = {
        'text_model': 'openai/clip-vit-base-patch32',
        'image_model': 'openai/clip-vit-base-patch32',
        'table_model': 'openai/clip-vit-base-patch32',
        'aggregator': 'attention',
        'embedding_dim': 512,
        'pruning': {
            'tag_blacklist': ['script', 'style'],
            'max_tokens_per_chunk': 2000
        }
    }

# %%
# dom_processor = TokenAwareDOMProcessor(config)

# %%
import json
def _collect_all_nodes(root_node) -> List:
    """收集DOM树中的所有节点 - 兼容dict和DOMNode对象"""
    nodes = []

    def dfs_collect(node):
        # 处理字典格式的节点（JSON数据）
        if isinstance(node, dict):
            # 只处理有全局ID的节点
            if node.get('metadata', {}).get('global_id'):
                nodes.append(node)

            # 递归处理子节点
            children = node.get('children', [])
            for child in children:
                dfs_collect(child)

        # 处理DOMNode对象
        elif hasattr(node, 'metadata') and node.metadata.get('global_id'):
            nodes.append(node)

            # 递归处理子节点
            if hasattr(node, 'children'):
                for child in node.children:
                    dfs_collect(child)

    dfs_collect(root_node)
    return nodes

# html_file_path = './../data/Demo/8e7c4cb542ad160f80fb3d795ada35d8.html'
# tree, chunks, process_logs = dom_processor.process_html_file(html_file_path)
# tree = build_global_tree_from_html(html_file_path, enable_table_grouping=True)

# 加载JSON格式的DOM树
with open("./data/dom/MMLongBench-Doc/welcome-to-nus.json", "r") as f:
    tree = json.load(f)

nodes = _collect_all_nodes(root_node=tree)
print(f"找到 {len(nodes)} 个节点")

# 显示前几个节点的信息
for i, node in enumerate(nodes[:3]):
    if isinstance(node, dict):
        node_id = node.get('metadata', {}).get('global_id', 'unknown')
        tag = node.get('tag', 'unknown')
        element_type = node.get('metadata', {}).get('element_type', '')
        print(f"节点 {i}: {tag}({element_type}) - ID: {node_id}")
    else:
        print(f"节点 {i}: {node}")
# Out:
# 找到 754 个节点
# 节点 0: document() - ID: doc_welcome-to-nus_54388
# 节点 1: p(paragraph) - ID: doc_welcome-to-nus_54389
# 节点 2: figure(figure) - ID: doc_welcome-to-nus_54390

# %%
nodes
# Out:
# [{'tag': 'document',
#   'metadata': {'depth': 0,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_54388',
#    'node_type': None,
#    'document_name': 'welcome-to-nus.pdf',
#    'page_count': 24,
#    'source_type': 'pdf_json'},
#   'children': [{'tag': 'p',
#     'text': 'Come',
#     'metadata': {'depth': 1,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_54389',
#      'node_type': None,
#      'original_index': 0,
#      'parent_chapter': -1,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 0,
#      'bbox': [603.5, 21.0, 863.0, 134.5],
#      'heading_level': None},
#     'data-page': '0'},
#    {'tag': 'figure',
#     'text': 'NUS National University of Singapore',
#     'metadata': {'depth': 1,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_54390',
#      'node_type': None,
#      'original_index': 1,
#      'parent_chapter': -1,
#      'is_chapter_title': False,
#      'element_type': 'figure',
#      'page_number': 0,
#      'bbox': [22.5, 334.0, 111.5, 379.5],
#      'image_extracted': True,
#      'ai_description': 'Skipped (disabled or too small)'},
#     'children': [{'tag': 'img',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54391',
#        'node_type': None},
#       'src': 'welcome-to-nus/page_1_figure_1.png'}],
#     'src': 'welcome-to-nus/page_1_figure_1.png',
#     'data-page': '0'},
#    {'tag': 'figure',
#     'text': '6',
#     'metadata': {'depth': 1,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_54392',
#      'node_type': None,
#      'original_index': 2,
#      'parent_chapter': -1,
#      'is_chapter_title': False,
#      'element_type': 'figure',
#      'page_number': 0,
#      'bbox': [209.0, 147.0, 861.0, 576.5],
#      'image_extracted': True,
#      'description_method': 'full_page_region',
#      'ai_description': '**Summary**: The target region contains a large, colorful sign with the text "NUSLife" and a person in a black dress with their arm raised, set against a green, outdoor background.\n\n**Content Details**:\n- Large, colorful "NUSLife" sign in orange and blue\n- Person in a black dress with their arm raised\n- Green, outdoor background with trees and steps\n- NUS logo and website URL (nus.edu.sg) on the left side\n- "NUS115" and "SHAPING THE FUTURE" text on the right side\n- "Welcome to NUS" text at the top in a decorative font\n\n**Visual Features**:\n- Bright, contrasting colors of the sign\n- Greenery and natural elements in the background\n- Person dressed in black, adding a human element to the scene\n\n**Context Integration**:\n- The region is part of a larger page welcoming new students to the National University of Singapore (NUS)\n- The colorful sign and outdoor setting suggest a vibrant and welcoming atmosphere\n- The person\'s raised arm could symbolize excitement or celebration\n\n**Purpose**:\n- The region serves as a welcoming and visually appealing introduction to the NUS campus, highlighting the university\'s name and the "NUSLife" experience\n- It aims to make new students feel included and excited about their future at NUS'},
#     'children': [{'tag': 'img',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54393',
#        'node_type': None},
#       'src': 'welcome-to-nus/page_1_figure_2.png'}],
#     'src': 'welcome-to-nus/page_1_figure_2.png',
#     'data-page': '0'},
#    {'tag': 'p',
#     'text': 'NUS 115',
#     'metadata': {'depth': 1,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_54394',
#      'node_type': None,
#      'original_index': 3,
#      'parent_chapter': -1,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 0,
#      'bbox': [472.9, 622.2, 533.8, 637.4],
#      'heading_level': None},
#     'data-page': '0'},
#    {'tag': 'p',
#     'text': 'SHAPING',
#     'metadata': {'depth': 1,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_54395',
#      'node_type': None,
#      'original_index': 4,
#      'parent_chapter': -1,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 0,
#      'bbox': [472.8, 640.2, 518.3, 648.8],
#      'heading_level': None},
#     'data-page': '0'},
#    {'tag': 'h1',
#     'text': 'THE FUTURE',
#     'metadata': {'depth': 1,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_54396',
#      'node_type': None,
#      'original_index': 5,
#      'parent_chapter': -1,
#      'is_chapter_title': True,
#      'element_type': 'paragraph',
#      'page_number': 0,
#      'bbox': [473.2, 650.5, 535.8, 658.9],
#      'heading_level': 1},
#     'children': [{'tag': 'p',
#       'text': '2020/2',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54397',
#        'node_type': None,
#        'original_index': 6,
#        'parent_chapter': 5,
#        'is_chapter_title': False,
#        'element_type': 'paragraph',
#        'page_number': 0,
#        'bbox': [783.5, 628.5, 844.0, 643.0],
#        'heading_level': None},
#       'data-page': '0'},
#      {'tag': 'figure',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54398',
#        'node_type': None,
#        'original_index': 7,
#        'parent_chapter': 5,
#        'is_chapter_title': False,
#        'element_type': 'figure',
#        'page_number': 1,
#        'bbox': [453.5, 15.0, 863.5, 493.5],
#        'image_extracted': True,
#        'description_method': 'full_page_region',
#        'ai_description': '**Summary**: The target region contains a large image of a building with a sign that reads "Welcome to NUS" and a contents page listing topics and page numbers.\n\n**Content Details**:\n- **Image**: A large, colorful photograph of a building with a prominent sign that says "Welcome to NUS" and includes the hashtag "#NUSBeyond".\n- **Contents Page**: A list of topics and corresponding page numbers, organized into sections such as "Starting Out", "Beyond the Classroom", and "Explore Campus Life".\n\n**Visual Features**:\n- **Colors**: Predominantly blue, green, and white, with a mix of text and graphics.\n- **Layout**: The contents page is structured with clear headings and a grid-like layout, making it easy to navigate.\n- **Text**: The text is in a readable font, with headings in a larger, bold font and subheadings in a smaller font.\n\n**Context Integration**:\n- The image and contents page are part of a student guide, likely for the National University of Singapore (NUS), given the "Welcome to NUS" sign.\n- The contents page provides an overview of what topics are covered in the guide, helping students find relevant information quickly.\n\n**Purpose**:\n- The image serves as a visual introduction to the university, setting a welcoming tone.\n- The contents page acts as a table of contents, guiding students to the specific information they need about living, learning, and thriving at NUS.'},
#       'children': [{'tag': 'img',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54399',
#          'node_type': None},
#         'src': 'welcome-to-nus/page_2_figure_7.png'}],
#       'src': 'welcome-to-nus/page_2_figure_7.png',
#       'data-page': '1'}],
#     'data-page': '0'},
#    {'tag': 'h1',
#     'text': 'CONTENTS',
#     'metadata': {'depth': 1,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_54400',
#      'node_type': None,
#      'original_index': 8,
#      'parent_chapter': -1,
#      'is_chapter_title': True,
#      'element_type': 'paragraph',
#      'page_number': 1,
#      'bbox': [476.0, 508.5, 540.5, 519.0],
#      'heading_level': 1},
#     'children': [{'tag': 'table',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54401',
#        'node_type': None,
#        'original_index': 9,
#        'parent_chapter': 8,
#        'is_chapter_title': False,
#        'element_type': 'table',
#        'page_number': 1,
#        'bbox': [474.5, 530.0, 839.5, 630.5],
#        'table_image_extracted': True},
#       'children': [{'tag': 'tr',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54402',
#          'node_type': None},
#         'children': [{'tag': 'td',
#           'text': 'STARTING\nOUT',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54403',
#            'node_type': None}},
#          {'tag': 'td',
#           'text': 'BEYOND THE\nCLASSROOM',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54404',
#            'node_type': None}},
#          {'tag': 'td',
#           'text': 'EXPLORE\nCAMPUS LIFE',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54405',
#            'node_type': None}}]},
#        {'tag': 'tr',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54406',
#          'node_type': None},
#         'children': [{'tag': 'td',
#           'text': '04 Our Campuses',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54407',
#            'node_type': None}},
#          {'tag': 'td',
#           'text': '14 Be an Entrepreneur',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54408',
#            'node_type': None}},
#          {'tag': 'td',
#           'text': '30 Campus Living',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54409',
#            'node_type': None}}]},
#        {'tag': 'tr',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54410',
#          'node_type': None},
#         'children': [{'tag': 'td',
#           'text': '06 Staying on Track',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54411',
#            'node_type': None}},
#          {'tag': 'td',
#           'text': '16 Making New Friends',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54412',
#            'node_type': None}},
#          {'tag': 'td',
#           'text': '34 Learning Resources',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54413',
#            'node_type': None}}]},
#        {'tag': 'tr',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54414',
#          'node_type': None},
#         'children': [{'tag': 'td',
#           'text': '08 Discover NUS',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54415',
#            'node_type': None}},
#          {'tag': 'td',
#           'text': '24 Caring for the Community \n& Environment',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54416',
#            'node_type': None}},
#          {'tag': 'td',
#           'text': '38 Food & Retail\n42 Student Services',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54417',
#            'node_type': None}}]}],
#       'src': 'welcome-to-nus/page_2_table_9.png',
#       'data-page': '1'},
#      {'tag': 'p',
#       'text': 'The student guide to living, learning and thriving at Singapore’s flagship university',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54418',
#        'node_type': None,
#        'original_index': 10,
#        'parent_chapter': 8,
#        'is_chapter_title': False,
#        'element_type': 'paragraph',
#        'page_number': 1,
#        'bbox': [476.0, 645.0, 811.5, 662.0],
#        'heading_level': None},
#       'data-page': '1'},
#      {'tag': 'figure',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54419',
#        'node_type': None,
#        'original_index': 11,
#        'parent_chapter': 8,
#        'is_chapter_title': False,
#        'element_type': 'figure',
#        'page_number': 2,
#        'bbox': [19.0, 0.0, 420.0, 497.0],
#        'image_extracted': True,
#        'description_method': 'full_page_region',
#        'ai_description': '**Summary**: The target region contains a photograph of three students working together, with the text "Starting OUT" and additional information about NUS\'s 115th anniversary and its global partnerships.\n\n**Content Details**:\n- **Photograph**: Three students are working together at a table, with one student using a laptop and the others holding pens and notebooks.\n- **Text**: "Starting OUT" in large, bold letters, followed by a description of NUS\'s 115th anniversary and its partnerships with top universities and countries.\n\n**Visual Features**:\n- **Colors**: Predominantly blue and orange, with a white background.\n- **Layout**: The photograph is on the left side, with the text on the right side, creating a balanced composition.\n- **Graphics**: The photograph is in color, while the text is in a mix of blue and orange fonts.\n\n**Context Integration**:\nThe target region is part of a larger document celebrating NUS\'s 115th anniversary. The photograph and text together highlight the university\'s commitment to education and global partnerships, emphasizing its role in shaping the future.\n\n**Purpose**:\nThe purpose of this content is to visually and textually communicate NUS\'s achievements and its ongoing efforts in education and international collaboration, appealing to prospective students and stakeholders.'},
#       'children': [{'tag': 'img',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54420',
#          'node_type': None},
#         'src': 'welcome-to-nus/page_3_figure_11.png'}],
#       'src': 'welcome-to-nus/page_3_figure_11.png',
#       'data-page': '2'}],
#     'data-page': '1'},
#    {'tag': 'h2',
#     'text': 'Starting  OUT',
#     'metadata': {'depth': 1,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_54421',
#      'node_type': None,
#      'original_index': 12,
#      'parent_chapter': -1,
#      'is_chapter_title': True,
#      'element_type': 'paragraph',
#      'page_number': 2,
#      'bbox': [232.5, 487.5, 440.0, 621.0],
#      'heading_level': 2},
#     'children': [{'tag': 'p',
#       'text': 'US commemorates its  115th year of founding in  2020. Established in 1905  as a modest medical school  with 23 students, NUS is  today widely known for  its innovative and rigorous  education, research and  entrepreneurship, which  has nurtured generations  of leaders and luminaries  across industries, professions  and sectors in Singapore and  beyond.',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54422',
#        'node_type': None,
#        'original_index': 13,
#        'parent_chapter': 12,
#        'is_chapter_title': False,
#        'element_type': 'paragraph',
#        'page_number': 2,
#        'bbox': [493.0, 23.5, 636.0, 220.5],
#        'heading_level': None},
#       'data-page': '2'},
#      {'tag': 'figure',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54423',
#        'node_type': None,
#        'original_index': 14,
#        'parent_chapter': 12,
#        'is_chapter_title': False,
#        'element_type': 'figure',
#        'page_number': 2,
#        'bbox': [472.0, 22.0, 497.5, 43.5],
#        'image_extracted': True,
#        'ai_description': 'Skipped (disabled or too small)'},
#       'children': [{'tag': 'img',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54424',
#          'node_type': None},
#         'src': 'welcome-to-nus/page_3_figure_14.png'}],
#       'src': 'welcome-to-nus/page_3_figure_14.png',
#       'data-page': '2'},
#      {'tag': 'figure',
#       'text': '3 CAMPUSES 17 SCHOOLS 11 NUS OVERSEAS  COLLEGES>70 DOUBLE, JOINT AND  CONCURRENT DEGREE  PROGRAMMES WITH THE  WORLD’S TOP UNIVERSITIES>300 PARTNER UNIVERSITIES  IN 40+ COUNTRIES FOR  STUDENT EXCHANGE  EXPERIENCES',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54425',
#        'node_type': None,
#        'original_index': 15,
#        'parent_chapter': 12,
#        'is_chapter_title': False,
#        'element_type': 'figure',
#        'page_number': 2,
#        'bbox': [659.5, 5.5, 836.5, 360.0],
#        'image_extracted': True,
#        'description_method': 'full_page_region',
#        'ai_description': "**Summary**: The target region contains a list of statistics and achievements related to NUS, including the number of campuses, schools, overseas colleges, double, joint, and concurrent degree programs, and partner universities for student exchange experiences.\n\n**Content Details**:\n- **Statistics**:\n  - 3 Campuses\n  - 17 Schools\n  - 11 NUS Overseas Colleges\n  - >70 Double, Joint, and Concurrent Degree Programmes\n  - >300 Partner Universities in 40+ Countries for Student Exchange Experiences\n\n- **Achievements**:\n  - NUS commemorates its 115th year of founding in 2020.\n  - NUS is known for its innovative and rigorous education, research, and entrepreneurship.\n  - NUS has nurtured generations of leaders and luminaries across various sectors.\n\n**Visual Features**:\n- The background is a light blue color with a gradient effect.\n- The text is in a mix of black and white, with some key numbers highlighted in orange.\n- There are icons next to each statistic, such as a building for campuses, a globe for overseas colleges, and a megaphone for degree programs.\n\n**Context Integration**:\nThe target region is part of a larger section that celebrates NUS's 115th anniversary and highlights its significant achievements and partnerships. The statistics and achievements are presented in a structured and visually appealing manner, emphasizing NUS's global reach and collaborative efforts.\n\n**Purpose**:\nThe purpose of this content is to provide readers with a concise overview of NUS's key statistics and achievements, showcasing its growth and impact over the years. The list format and highlighted numbers make it easy to quickly grasp the scale and scope of NUS's operations and partnerships."},
#       'children': [{'tag': 'img',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54426',
#          'node_type': None},
#         'src': 'welcome-to-nus/page_3_figure_15.png'}],
#       'src': 'welcome-to-nus/page_3_figure_15.png',
#       'data-page': '2'},
#      {'tag': 'p',
#       'text': 'With NUS115, we proudly  celebrate the University’s  transformative impact over  115 years and its continual  eforts at shaping the future  for a better world.',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54427',
#        'node_type': None,
#        'original_index': 16,
#        'parent_chapter': 12,
#        'is_chapter_title': False,
#        'element_type': 'paragraph',
#        'page_number': 2,
#        'bbox': [501.5, 233.0, 631.0, 313.5],
#        'heading_level': None},
#       'data-page': '2'},
#      {'tag': 'p',
#       'text': 'Find out more at nus115.sg.',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54428',
#        'node_type': None,
#        'original_index': 17,
#        'parent_chapter': 12,
#        'is_chapter_title': False,
#        'element_type': 'paragraph',
#        'page_number': 2,
#        'bbox': [502.5, 330.5, 628.0, 341.0],
#        'heading_level': None},
#       'data-page': '2'},
#      {'tag': 'figure',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54429',
#        'node_type': None,
#        'original_index': 18,
#        'parent_chapter': 12,
#        'is_chapter_title': False,
#        'element_type': 'figure',
#        'page_number': 2,
#        'bbox': [459.0, 442.0, 857.0, 674.0],
#        'image_extracted': True,
#        'description_method': 'full_page_region',
#        'ai_description': "**Summary**: The target region contains a list of statistics and achievements related to NUS, including the number of campuses, schools, overseas colleges, double, joint, and concurrent degree programs, and partner universities for student exchange experiences.\n\n**Content Details**:\n- **Statistics**:\n  - 3 Campuses\n  - 17 Schools\n  - 11 NUS Overseas Colleges\n  - >70 Double, Joint, and Concurrent Degree Programmes\n  - >300 Partner Universities in 40+ Countries\n\n- **Achievements**:\n  - Celebrates NUS's 115th year of founding\n  - NUS is known for its innovative and rigorous education, research, and entrepreneurship\n  - NUS has nurtured generations of leaders and luminaries across various sectors\n\n**Visual Features**:\n- The content is presented in a light blue background with orange and white text, using bullet points for clarity.\n- The text is organized in a structured format, making it easy to read and understand the key statistics and achievements.\n\n**Context Integration**:\nThe target region is part of a larger document that commemorates NUS's 115th anniversary. It provides a concise summary of NUS's significant milestones and achievements, highlighting its growth and impact over the years.\n\n**Purpose**:\nThe purpose of this content is to inform and celebrate NUS's 115 years of excellence in education, research, and entrepreneurship, showcasing its global reach and partnerships."},
#       'children': [{'tag': 'img',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54430',
#          'node_type': None},
#         'src': 'welcome-to-nus/page_3_figure_18.png'}],
#       'src': 'welcome-to-nus/page_3_figure_18.png',
#       'data-page': '2'},
#      {'tag': 'h2',
#       'text': 'OUR  CAMPUSES',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54431',
#        'node_type': None,
#        'original_index': 19,
#        'parent_chapter': 12,
#        'is_chapter_title': True,
#        'element_type': 'paragraph',
#        'page_number': 3,
#        'bbox': [22.0, 22.0, 179.0, 90.0],
#        'heading_level': 2},
#       'children': [{'tag': 'h2',
#         'text': 'KENT RIDGE CAMPUS',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54432',
#          'node_type': None,
#          'original_index': 20,
#          'parent_chapter': 19,
#          'is_chapter_title': True,
#          'element_type': 'paragraph',
#          'page_number': 3,
#          'bbox': [32.0, 106.0, 140.0, 115.5],
#          'heading_level': 2},
#         'children': [{'tag': 'p',
#           'text': 'NUS’ main campus since 1980,  the sprawling 150-hectare Kent Ridge  Campus hosts most of the University’s  academic, research and administrative  facilities. It is also a bustling hub of  student life, with student residences,  sports facilities and venues for arts  and cultural activities.',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54433',
#            'node_type': None,
#            'original_index': 21,
#            'parent_chapter': 20,
#            'is_chapter_title': False,
#            'element_type': 'paragraph',
#            'page_number': 3,
#            'bbox': [31.0, 117.5, 196.0, 220.5],
#            'heading_level': None},
#           'data-page': '3'},
#          {'tag': 'p',
#           'text': 'University Town (UTown) – an extension of  the Kent Ridge Campus – ofers a unique  residential college experience, as well as  a host of educational and recreational  spaces for interaction, peer learning and  personal development. UTown is also home  to Yale-NUS College, Singapore’s first  liberal arts college with a full residential  programme.',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54434',
#            'node_type': None,
#            'original_index': 22,
#            'parent_chapter': 20,
#            'is_chapter_title': False,
#            'element_type': 'paragraph',
#            'page_number': 3,
#            'bbox': [221.5, 104.0, 405.0, 222.5],
#            'heading_level': None},
#           'data-page': '3'},
#          {'tag': 'p',
#           'text': 'PHOTO CREDIT: RORY GARDINER',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54435',
#            'node_type': None,
#            'original_index': 23,
#            'parent_chapter': 20,
#            'is_chapter_title': False,
#            'element_type': 'paragraph',
#            'page_number': 3,
#            'bbox': [314.5, 246.0, 398.5, 252.0],
#            'heading_level': None},
#           'data-page': '3'}],
#         'data-page': '3'},
#        {'tag': 'h1',
#         'text': 'BUKIT TIMAH CAMPUS',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54436',
#          'node_type': None,
#          'original_index': 24,
#          'parent_chapter': 19,
#          'is_chapter_title': True,
#          'element_type': 'paragraph',
#          'page_number': 3,
#          'bbox': [471.5, 295.5, 585.0, 305.0],
#          'heading_level': 1},
#         'children': [{'tag': 'p',
#           'text': 'The Bukit Timah Campus houses  the Faculty of Law and the  Lee Kuan Yew School of Public  Policy. The colonial style buildings  date back to 1928 when  NUS’ predecessor institution,  Rafles College, was established.',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54437',
#            'node_type': None,
#            'original_index': 25,
#            'parent_chapter': 24,
#            'is_chapter_title': False,
#            'element_type': 'paragraph',
#            'page_number': 3,
#            'bbox': [471.5, 307.5, 616.5, 399.5],
#            'heading_level': None},
#           'data-page': '3'},
#          {'tag': 'figure',
#           'text': 'OUTRAM CAMPUS',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54438',
#            'node_type': None,
#            'original_index': 26,
#            'parent_chapter': 24,
#            'is_chapter_title': False,
#            'element_type': 'figure',
#            'page_number': 3,
#            'bbox': [470.5, 476.0, 688.0, 645.0],
#            'image_extracted': True,
#            'description_method': 'full_page_region',
#            'ai_description': '**Summary**: The target region contains images and descriptions of the University Town (UTown) and the Kent Ridge Campus, highlighting its academic, research, and residential facilities.\n\n**Content Details**:\n- **Images**: Two photographs of the University Town and the Kent Ridge Campus.\n- **Text**: Descriptions of the University Town and the Kent Ridge Campus, mentioning its academic, research, and residential facilities.\n\n**Visual Features**:\n- **Colors**: Predominantly green from the grass and trees, with blue and white from the buildings.\n- **Layout**: Images are placed on the right side, with text descriptions on the left.\n- **Text**: Black text on a white background, with a blue header.\n\n**Context Integration**:\n- The target region is part of a larger section titled "OUR CAMPUSES," which provides an overview of the various campuses of the University.\n- The images and descriptions are likely used to visually showcase the University Town and the Kent Ridge Campus, emphasizing their importance and features.\n\n**Purpose**:\n- The purpose of this content is to inform readers about the University Town and the Kent Ridge Campus, highlighting their significance in the university\'s academic, research, and residential offerings.'},
#           'children': [{'tag': 'img',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54439',
#              'node_type': None},
#             'src': 'welcome-to-nus/page_4_figure_26.png'}],
#           'src': 'welcome-to-nus/page_4_figure_26.png',
#           'data-page': '3'},
#          {'tag': 'p',
#           'text': 'THE KENT RIDGE CAMPUS IS HOME TO SINGAPORE’S FIRST NEW-BUILD NET-ZERO  ENERGY BUILDING AT THE NUS SCHOOL OF DESIGN AND ENVIRONMENT',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54440',
#            'node_type': None,
#            'original_index': 27,
#            'parent_chapter': 24,
#            'is_chapter_title': False,
#            'element_type': 'paragraph',
#            'page_number': 3,
#            'bbox': [136.5, 615.5, 402.5, 641.0],
#            'heading_level': None},
#           'data-page': '3'},
#          {'tag': 'figure',
#           'text': 'UNIVERSITY TOWN',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54441',
#            'node_type': None,
#            'original_index': 28,
#            'parent_chapter': 24,
#            'is_chapter_title': False,
#            'element_type': 'figure',
#            'page_number': 3,
#            'bbox': [467.5, 27.5, 847.5, 272.5],
#            'image_extracted': True,
#            'description_method': 'full_page_region',
#            'ai_description': '**Summary**: The target region contains images and descriptions of the University Town (UTown) and the Kent Ridge Campus, highlighting their academic, residential, and recreational facilities.\n\n**Content Details**:\n- **Images**: Two photographs of the University Town and the Kent Ridge Campus.\n- **Text**: Descriptions of the University Town and the Kent Ridge Campus, mentioning academic, residential, and recreational facilities.\n- **Credit**: Photo credit to Rory Gardiner.\n\n**Visual Features**:\n- **Colors**: Predominantly green from the grass and trees, with blue and white from the buildings.\n- **Layout**: Two columns of text with images on the left and right, respectively.\n- **Text**: Black text on a white background.\n\n**Context Integration**:\n- The target region is part of a larger section titled "Our Campuses," which provides an overview of the various campuses of the University.\n- The images and descriptions complement the text, offering visual context to the academic and residential facilities mentioned.\n\n**Purpose**:\n- The purpose of this content is to provide a visual and textual overview of the University Town and the Kent Ridge Campus, highlighting their importance as academic, residential, and recreational hubs for the university community.'},
#           'children': [{'tag': 'img',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54442',
#              'node_type': None},
#             'src': 'welcome-to-nus/page_4_figure_28.png'}],
#           'src': 'welcome-to-nus/page_4_figure_28.png',
#           'data-page': '3'},
#          {'tag': 'figure',
#           'text': 'BUKIT TIMAH CAMPUS',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54443',
#            'node_type': None,
#            'original_index': 29,
#            'parent_chapter': 24,
#            'is_chapter_title': False,
#            'element_type': 'figure',
#            'page_number': 3,
#            'bbox': [627.5, 292.5, 846.5, 459.0],
#            'image_extracted': True,
#            'description_method': 'full_page_region',
#            'ai_description': '**Summary**: The target region contains images and descriptions of the University Town (UTown) and the Kent Ridge Campus, highlighting their features and significance within the NUS campus.\n\n**Content Details**:\n- **Images**: Two photographs of the University Town and the Kent Ridge Campus.\n- **Text**: Descriptions of the University Town and the Kent Ridge Campus, mentioning its academic, research, and administrative facilities, as well as student life and residential college experience.\n\n**Visual Features**:\n- **Colors**: Predominantly green from the grass and trees, with blue and white from the buildings.\n- **Layout**: The text is aligned to the left, with images placed to the right, creating a balanced layout.\n- **Text**: The text is in black, with some words highlighted in blue for emphasis.\n\n**Context Integration**:\n- The target region is part of a larger section titled "OUR CAMPUSES," which provides an overview of the various campuses of the National University of Singapore (NUS).\n- The images and descriptions complement the text, offering visual context to the information provided.\n\n**Purpose**:\n- The purpose of this content is to inform readers about the University Town and the Kent Ridge Campus, their facilities, and their role within the NUS campus.'},
#           'children': [{'tag': 'img',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54444',
#              'node_type': None},
#             'src': 'welcome-to-nus/page_4_figure_29.png'}],
#           'src': 'welcome-to-nus/page_4_figure_29.png',
#           'data-page': '3'}],
#         'data-page': '3'},
#        {'tag': 'h2',
#         'text': 'OUTRAM CAMPUS',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54445',
#          'node_type': None,
#          'original_index': 30,
#          'parent_chapter': 19,
#          'is_chapter_title': True,
#          'element_type': 'paragraph',
#          'page_number': 3,
#          'bbox': [701.5, 478.0, 793.5, 487.5],
#          'heading_level': 2},
#         'children': [{'tag': 'p',
#           'text': 'Located among many of the  nation’s key medical institutions,  the Outram Campus houses the  Duke-NUS Medical School  (Duke-NUS). Duke-NUS’  innovative medical education  programme with a distinctive  research focus is designed to  develop medical leaders in  research, education and  patient care.',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54446',
#            'node_type': None,
#            'original_index': 31,
#            'parent_chapter': 30,
#            'is_chapter_title': False,
#            'element_type': 'paragraph',
#            'page_number': 3,
#            'bbox': [699.5, 490.5, 841.5, 633.5],
#            'heading_level': None},
#           'data-page': '3'},
#          {'tag': 'footer',
#           'text': '04',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54447',
#            'node_type': None,
#            'original_index': 32,
#            'parent_chapter': 30,
#            'is_chapter_title': False,
#            'element_type': 'page_footer',
#            'page_number': 3,
#            'bbox': [34.0, 663.0, 46.5, 671.5]},
#           'data-page': '3'},
#          {'tag': 'footer',
#           'text': '05',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54448',
#            'node_type': None,
#            'original_index': 33,
#            'parent_chapter': 30,
#            'is_chapter_title': False,
#            'element_type': 'page_footer',
#            'page_number': 3,
#            'bbox': [831.0, 663.0, 842.5, 671.5]},
#           'data-page': '3'}],
#         'data-page': '3'}],
#       'data-page': '3'},
#      {'tag': 'h1',
#       'text': 'STAYING ON TRACK',
#       'metadata': {'depth': 2,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_54449',
#        'node_type': None,
#        'original_index': 34,
#        'parent_chapter': 12,
#        'is_chapter_title': True,
#        'element_type': 'paragraph',
#        'page_number': 4,
#        'bbox': [28.5, 33.0, 187.5, 84.5],
#        'heading_level': 1},
#       'children': [{'tag': 'p',
#         'text': 'VERY academic year comprises two semesters and a special term.  Each semester has 13 weeks of classes and two weeks of examinations.',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54450',
#          'node_type': None,
#          'original_index': 35,
#          'parent_chapter': 34,
#          'is_chapter_title': False,
#          'element_type': 'paragraph',
#          'page_number': 4,
#          'bbox': [33.0, 100.5, 395.5, 138.0],
#          'heading_level': None},
#         'data-page': '4'},
#        {'tag': 'figure',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54451',
#          'node_type': None,
#          'original_index': 36,
#          'parent_chapter': 34,
#          'is_chapter_title': False,
#          'element_type': 'figure',
#          'page_number': 4,
#          'bbox': [27.5, 146.0, 412.0, 649.5],
#          'image_extracted': True,
#          'description_method': 'full_page_region',
#          'ai_description': '**Summary**: The target region contains a detailed academic calendar for the academic year 2020/2021, including semester dates, holidays, and special weeks.\n\n**Content Details**:\n- **Semester 1** (Mon 3 Aug 2020 – Sat 5 Dec 2020): 18 weeks\n  - Orientation Week: Mon 3 Aug 2020 – Sat 8 Aug 2020\n  - Instructional Period: Mon 10 Aug 2020 – Fri 18 Sep 2020\n  - Recess Week: Sat 19 Sep 2020 – Sun 27 Sep 2020\n  - Instructional Period: Mon 28 Sep 2020 – Fri 13 Nov 2020\n  - Reading Week: Sat 14 Nov 2020 – Fri 20 Nov 2020\n  - Examination: Sat 21 Nov 2020 – Sat 5 Dec 2020\n  - Vacation: Sun 6 Dec 2020 – Sun 10 Jan 2021\n- **Semester 2** (Mon 11 Jan 2021 – Sat 8 May 2021): 17 weeks\n  - Instructional Period: Mon 11 Jan 2021 – Fri 19 Feb 2021\n  - Recess Week: Sat 20 Feb 2021 – Sun 28 Feb 2021\n  - Instructional Period: Mon 1 Mar 2021 – Fri 16 Apr 2021\n  - Reading Week: Sat 17 Apr 2021 – Fri 23 Apr 2021\n  - Examination: Sat 24 Apr 2021 – Sat 8 May 2021\n  - Vacation: Sun 9 May 2021 – Sun 1 Aug 2021\n- **Special Term** (Mon 10 May 2021 – Sat 31 Jul 2021): 12 weeks\n  - Mon 10 May 2021 – Sat 19 Jun 2021\n  -'},
#         'children': [{'tag': 'img',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54452',
#            'node_type': None},
#           'src': 'welcome-to-nus/page_5_figure_36.png'}],
#         'src': 'welcome-to-nus/page_5_figure_36.png',
#         'data-page': '4'},
#        {'tag': 'h2',
#         'text': 'ORIENTATION WEEK RECESS WEEKREADING WEEK',
#         'metadata': {'depth': 3,
#          'page_id': None,
#          'global_id': 'doc_welcome-to-nus_54453',
#          'node_type': None,
#          'original_index': 37,
#          'parent_chapter': 34,
#          'is_chapter_title': True,
#          'element_type': 'paragraph',
#          'page_number': 4,
#          'bbox': [491.9, 97.8, 814.7, 105.0],
#          'heading_level': 2},
#         'children': [{'tag': 'h2',
#           'text': 'The start of a new Grab a well-deserved The last lap before',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54454',
#            'node_type': None,
#            'original_index': 38,
#            'parent_chapter': 37,
#            'is_chapter_title': True,
#            'element_type': 'paragraph',
#            'page_number': 4,
#            'bbox': [503.4, 110.6, 814.2, 119.8],
#            'heading_level': 2},
#           'data-page': '4'},
#          {'tag': 'h2',
#           'text': 'academic year. breather from your the start of',
#           'metadata': {'depth': 4,
#            'page_id': None,
#            'global_id': 'doc_welcome-to-nus_54455',
#            'node_type': None,
#            'original_index': 39,
#            'parent_chapter': 37,
#            'is_chapter_title': True,
#            'element_type': 'paragraph',
#            'page_number': 4,
#            'bbox': [510.6, 123.6, 798.9, 132.9],
#            'heading_level': 2},
#           'children': [{'tag': 'p',
#             'text': 'studies, or catch up on examination season;',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54456',
#              'node_type': None,
#              'original_index': 40,
#              'parent_chapter': 39,
#              'is_chapter_title': False,
#              'element_type': 'paragraph',
#              'page_number': 4,
#              'bbox': [611.7, 136.6, 818.6, 145.8],
#              'heading_level': None},
#             'data-page': '4'},
#            {'tag': 'p',
#             'text': 'Get a sense of the  University and forge  new friendships before you get busy with  study sessions and',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54457',
#              'node_type': None,
#              'original_index': 41,
#              'parent_chapter': 39,
#              'is_chapter_title': False,
#              'element_type': 'paragraph',
#              'page_number': 4,
#              'bbox': [492.5, 135.5, 590.0, 203.5],
#              'heading_level': None},
#             'data-page': '4'},
#            {'tag': 'p',
#             'text': 'subjects you need selected libraries',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54458',
#              'node_type': None,
#              'original_index': 42,
#              'parent_chapter': 39,
#              'is_chapter_title': False,
#              'element_type': 'paragraph',
#              'page_number': 4,
#              'bbox': [621.4, 149.6, 810.5, 158.9],
#              'heading_level': None},
#             'data-page': '4'},
#            {'tag': 'p',
#             'text': 'more time on. will be open',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54459',
#              'node_type': None,
#              'original_index': 43,
#              'parent_chapter': 39,
#              'is_chapter_title': False,
#              'element_type': 'paragraph',
#              'page_number': 4,
#              'bbox': [629.9, 162.6, 800.9, 171.8],
#              'heading_level': None},
#             'data-page': '4'},
#            {'tag': 'p',
#             'text': '24 hours.',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54460',
#              'node_type': None,
#              'original_index': 44,
#              'parent_chapter': 39,
#              'is_chapter_title': False,
#              'element_type': 'paragraph',
#              'page_number': 4,
#              'bbox': [756.6, 175.6, 794.6, 182.9],
#              'heading_level': None},
#             'data-page': '4'},
#            {'tag': 'table',
#             'metadata': {'depth': 5,
#              'page_id': None,
#              'global_id': 'doc_welcome-to-nus_54461',
#              'node_type': None,
#              'original_index': 45,
#              'parent_chapter': 39,
#              'is_chapter_title': False,
#              'element_type': 'table',
#              'page_number': 4,
#              'bbox': [450.5, 230.0, 851.0, 561.5],
#              'table_image_extracted': True},
#             'children': [{'tag': 'tr',
#               'metadata': {'depth': 6,
#                'page_id': None,
#                'global_id': 'doc_welcome-to-nus_54462',
#                'node_type': None},
#               'children': [{'tag': 'td',
#                 'text': 'Semester 1',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54463',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': 'Mon 3 Aug 2020 – Sat 5 Dec 2020',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54464',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': '18 weeks',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54465',
#                  'node_type': None}}]},
#              {'tag': 'tr',
#               'metadata': {'depth': 6,
#                'page_id': None,
#                'global_id': 'doc_welcome-to-nus_54466',
#                'node_type': None},
#               'children': [{'tag': 'td',
#                 'text': 'Orientation Week',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54467',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': 'Mon 3 Aug 2020 – Sat 8 Aug 2020',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54468',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': '1 week',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54469',
#                  'node_type': None}}]},
#              {'tag': 'tr',
#               'metadata': {'depth': 6,
#                'page_id': None,
#                'global_id': 'doc_welcome-to-nus_54470',
#                'node_type': None},
#               'children': [{'tag': 'td',
#                 'text': 'Instructional Period',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54471',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': 'Mon 10 Aug 2020 – Fri 18 Sep 2020',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54472',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': '6 weeks',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54473',
#                  'node_type': None}}]},
#              {'tag': 'tr',
#               'metadata': {'depth': 6,
#                'page_id': None,
#                'global_id': 'doc_welcome-to-nus_54474',
#                'node_type': None},
#               'children': [{'tag': 'td',
#                 'text': 'Recess Week',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54475',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': 'Sat 19 Sep 2020 – Sun 27 Sep 2020',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54476',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': '1 week',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54477',
#                  'node_type': None}}]},
#              {'tag': 'tr',
#               'metadata': {'depth': 6,
#                'page_id': None,
#                'global_id': 'doc_welcome-to-nus_54478',
#                'node_type': None},
#               'children': [{'tag': 'td',
#                 'text': 'Instructional Period',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54479',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': 'Mon 28 Sep 2020 – Fri 13 Nov 2020',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54480',
#                  'node_type': None}},
#                {'tag': 'td',
#                 'text': '7 weeks',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54481',
#                  'node_type': None}}]},
#              {'tag': 'tr',
#               'metadata': {'depth': 6,
#                'page_id': None,
#                'global_id': 'doc_welcome-to-nus_54482',
#                'node_type': None},
#               'children': [{'tag': 'td',
#                 'text': 'Reading Week',
#                 'metadata': {'depth': 7,
#                  'page_id': None,
#                  'global_id': 'doc_welcome-to-nus_54483',
#                  'node_type': None}},
#                {'tag': 'td',
# ...
#    'bbox': [33.0, 663.0, 45.5, 671.5]},
#   'data-page': '22'},
#  {'tag': 'footer',
#   'text': '43',
#   'metadata': {'depth': 4,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55121',
#    'node_type': None,
#    'original_index': 675,
#    'parent_chapter': 672,
#    'is_chapter_title': False,
#    'element_type': 'page_footer',
#    'page_number': 22,
#    'bbox': [829.5, 663.0, 842.0, 671.5]},
#   'data-page': '22'},
#  {'tag': 'figure',
#   'metadata': {'depth': 4,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55122',
#    'node_type': None,
#    'original_index': 676,
#    'parent_chapter': 672,
#    'is_chapter_title': False,
#    'element_type': 'figure',
#    'page_number': 23,
#    'bbox': [13.0, 12.5, 421.0, 458.0],
#    'image_extracted': True,
#    'description_method': 'full_page_region',
#    'ai_description': "**Summary**: The target region contains a promotional image of a National University of Singapore (NUS) shuttle bus, along with social media and website links for NUS.\n\n**Content Details**:\n- **Image**: A brightly colored NUS shuttle bus with the university's logo and name prominently displayed.\n- **Social Media Links**: Facebook, Instagram, LinkedIn, Twitter, and WeChat accounts for NUS.\n- **Website**: nus.edu.sg\n\n**Visual Features**:\n- The image is vibrant and eye-catching, featuring the NUS logo and colors.\n- The social media icons are colorful and recognizable.\n- The text is clear and easy to read.\n\n**Context Integration**:\n- The image and links are part of a larger promotional or informational page, likely from the NUS Office of University Communications.\n- The shuttle bus image suggests NUS's campus transportation system, which is a practical and important aspect of university life.\n\n**Purpose**:\n- The purpose of this region is to promote NUS and its social media presence, encouraging students, alumni, and visitors to follow and engage with the university on various platforms.\n- It also serves as a visual representation of NUS's campus, highlighting the university's commitment to providing a modern and accessible environment for its students."},
#   'children': [{'tag': 'img',
#     'metadata': {'depth': 5,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55123',
#      'node_type': None},
#     'src': 'welcome-to-nus/page_24_figure_676.png'}],
#   'src': 'welcome-to-nus/page_24_figure_676.png',
#   'data-page': '23'},
#  {'tag': 'img',
#   'metadata': {'depth': 5,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55123',
#    'node_type': None},
#   'src': 'welcome-to-nus/page_24_figure_676.png'},
#  {'tag': 'h1',
#   'text': 'FOLLOW US',
#   'metadata': {'depth': 1,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55124',
#    'node_type': None,
#    'original_index': 677,
#    'parent_chapter': -1,
#    'is_chapter_title': True,
#    'element_type': 'paragraph',
#    'page_number': 23,
#    'bbox': [37.0, 477.0, 141.0, 493.5],
#    'heading_level': 1},
#   'children': [{'tag': 'figure',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55125',
#      'node_type': None,
#      'original_index': 678,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'figure',
#      'page_number': 23,
#      'bbox': [37.0, 508.5, 54.0, 525.5],
#      'image_extracted': True,
#      'ai_description': 'Skipped (disabled or too small)'},
#     'children': [{'tag': 'img',
#       'metadata': {'depth': 3,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_55126',
#        'node_type': None},
#       'src': 'welcome-to-nus/page_24_figure_678.png'}],
#     'src': 'welcome-to-nus/page_24_figure_678.png',
#     'data-page': '23'},
#    {'tag': 'p',
#     'text': 'facebook.com/nus.singapore',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55127',
#      'node_type': None,
#      'original_index': 679,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 23,
#      'bbox': [54.0, 509.5, 183.5, 524.5],
#      'heading_level': None},
#     'data-page': '23'},
#    {'tag': 'figure',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55128',
#      'node_type': None,
#      'original_index': 680,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'figure',
#      'page_number': 23,
#      'bbox': [36.0, 538.0, 53.0, 554.0],
#      'image_extracted': True,
#      'ai_description': 'Skipped (disabled or too small)'},
#     'children': [{'tag': 'img',
#       'metadata': {'depth': 3,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_55129',
#        'node_type': None},
#       'src': 'welcome-to-nus/page_24_figure_680.png'}],
#     'src': 'welcome-to-nus/page_24_figure_680.png',
#     'data-page': '23'},
#    {'tag': 'p',
#     'text': 'instagram.com/nus_singapore',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55130',
#      'node_type': None,
#      'original_index': 681,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 23,
#      'bbox': [36.0, 538.0, 189.0, 555.0],
#      'heading_level': None},
#     'data-page': '23'},
#    {'tag': 'p',
#     'text': 'nus.edu/linkedin',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55131',
#      'node_type': None,
#      'original_index': 682,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 23,
#      'bbox': [35.0, 567.0, 132.5, 585.0],
#      'heading_level': None},
#     'data-page': '23'},
#    {'tag': 'p',
#     'text': 'twitter.com/NUSingapore',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55132',
#      'node_type': None,
#      'original_index': 683,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 23,
#      'bbox': [37.0, 598.5, 170.5, 612.5],
#      'heading_level': None},
#     'data-page': '23'},
#    {'tag': 'p',
#     'text': 'NUS_Singapore',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55133',
#      'node_type': None,
#      'original_index': 684,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 23,
#      'bbox': [52.0, 627.5, 126.0, 643.0],
#      'heading_level': None},
#     'data-page': '23'},
#    {'tag': 'figure',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55134',
#      'node_type': None,
#      'original_index': 685,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'figure',
#      'page_number': 23,
#      'bbox': [36.0, 625.0, 54.0, 644.0],
#      'image_extracted': True,
#      'ai_description': 'Skipped (disabled or too small)'},
#     'children': [{'tag': 'img',
#       'metadata': {'depth': 3,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_55135',
#        'node_type': None},
#       'src': 'welcome-to-nus/page_24_figure_685.png'}],
#     'src': 'welcome-to-nus/page_24_figure_685.png',
#     'data-page': '23'},
#    {'tag': 'figure',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55136',
#      'node_type': None,
#      'original_index': 686,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'figure',
#      'page_number': 23,
#      'bbox': [811.0, 455.5, 856.0, 502.5],
#      'image_extracted': True,
#      'ai_description': 'Skipped (disabled or too small)'},
#     'children': [{'tag': 'img',
#       'metadata': {'depth': 3,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_55137',
#        'node_type': None},
#       'src': 'welcome-to-nus/page_24_figure_686.png'}],
#     'src': 'welcome-to-nus/page_24_figure_686.png',
#     'data-page': '23'},
#    {'tag': 'p',
#     'text': 'nus.edu.sg',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55138',
#      'node_type': None,
#      'original_index': 687,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'paragraph',
#      'page_number': 23,
#      'bbox': [811.0, 511.5, 850.5, 521.5],
#      'heading_level': None},
#     'data-page': '23'},
#    {'tag': 'figure',
#     'metadata': {'depth': 2,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55139',
#      'node_type': None,
#      'original_index': 688,
#      'parent_chapter': 677,
#      'is_chapter_title': False,
#      'element_type': 'figure',
#      'page_number': 23,
#      'bbox': [751.0, 587.0, 855.5, 636.0],
#      'image_extracted': True,
#      'ai_description': 'Skipped (disabled or too small)'},
#     'children': [{'tag': 'img',
#       'metadata': {'depth': 3,
#        'page_id': None,
#        'global_id': 'doc_welcome-to-nus_55140',
#        'node_type': None},
#       'src': 'welcome-to-nus/page_24_figure_688.png'}],
#     'src': 'welcome-to-nus/page_24_figure_688.png',
#     'data-page': '23'}],
#   'data-page': '23'},
#  {'tag': 'figure',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55125',
#    'node_type': None,
#    'original_index': 678,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'figure',
#    'page_number': 23,
#    'bbox': [37.0, 508.5, 54.0, 525.5],
#    'image_extracted': True,
#    'ai_description': 'Skipped (disabled or too small)'},
#   'children': [{'tag': 'img',
#     'metadata': {'depth': 3,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55126',
#      'node_type': None},
#     'src': 'welcome-to-nus/page_24_figure_678.png'}],
#   'src': 'welcome-to-nus/page_24_figure_678.png',
#   'data-page': '23'},
#  {'tag': 'img',
#   'metadata': {'depth': 3,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55126',
#    'node_type': None},
#   'src': 'welcome-to-nus/page_24_figure_678.png'},
#  {'tag': 'p',
#   'text': 'facebook.com/nus.singapore',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55127',
#    'node_type': None,
#    'original_index': 679,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'paragraph',
#    'page_number': 23,
#    'bbox': [54.0, 509.5, 183.5, 524.5],
#    'heading_level': None},
#   'data-page': '23'},
#  {'tag': 'figure',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55128',
#    'node_type': None,
#    'original_index': 680,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'figure',
#    'page_number': 23,
#    'bbox': [36.0, 538.0, 53.0, 554.0],
#    'image_extracted': True,
#    'ai_description': 'Skipped (disabled or too small)'},
#   'children': [{'tag': 'img',
#     'metadata': {'depth': 3,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55129',
#      'node_type': None},
#     'src': 'welcome-to-nus/page_24_figure_680.png'}],
#   'src': 'welcome-to-nus/page_24_figure_680.png',
#   'data-page': '23'},
#  {'tag': 'img',
#   'metadata': {'depth': 3,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55129',
#    'node_type': None},
#   'src': 'welcome-to-nus/page_24_figure_680.png'},
#  {'tag': 'p',
#   'text': 'instagram.com/nus_singapore',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55130',
#    'node_type': None,
#    'original_index': 681,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'paragraph',
#    'page_number': 23,
#    'bbox': [36.0, 538.0, 189.0, 555.0],
#    'heading_level': None},
#   'data-page': '23'},
#  {'tag': 'p',
#   'text': 'nus.edu/linkedin',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55131',
#    'node_type': None,
#    'original_index': 682,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'paragraph',
#    'page_number': 23,
#    'bbox': [35.0, 567.0, 132.5, 585.0],
#    'heading_level': None},
#   'data-page': '23'},
#  {'tag': 'p',
#   'text': 'twitter.com/NUSingapore',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55132',
#    'node_type': None,
#    'original_index': 683,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'paragraph',
#    'page_number': 23,
#    'bbox': [37.0, 598.5, 170.5, 612.5],
#    'heading_level': None},
#   'data-page': '23'},
#  {'tag': 'p',
#   'text': 'NUS_Singapore',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55133',
#    'node_type': None,
#    'original_index': 684,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'paragraph',
#    'page_number': 23,
#    'bbox': [52.0, 627.5, 126.0, 643.0],
#    'heading_level': None},
#   'data-page': '23'},
#  {'tag': 'figure',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55134',
#    'node_type': None,
#    'original_index': 685,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'figure',
#    'page_number': 23,
#    'bbox': [36.0, 625.0, 54.0, 644.0],
#    'image_extracted': True,
#    'ai_description': 'Skipped (disabled or too small)'},
#   'children': [{'tag': 'img',
#     'metadata': {'depth': 3,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55135',
#      'node_type': None},
#     'src': 'welcome-to-nus/page_24_figure_685.png'}],
#   'src': 'welcome-to-nus/page_24_figure_685.png',
#   'data-page': '23'},
#  {'tag': 'img',
#   'metadata': {'depth': 3,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55135',
#    'node_type': None},
#   'src': 'welcome-to-nus/page_24_figure_685.png'},
#  {'tag': 'figure',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55136',
#    'node_type': None,
#    'original_index': 686,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'figure',
#    'page_number': 23,
#    'bbox': [811.0, 455.5, 856.0, 502.5],
#    'image_extracted': True,
#    'ai_description': 'Skipped (disabled or too small)'},
#   'children': [{'tag': 'img',
#     'metadata': {'depth': 3,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55137',
#      'node_type': None},
#     'src': 'welcome-to-nus/page_24_figure_686.png'}],
#   'src': 'welcome-to-nus/page_24_figure_686.png',
#   'data-page': '23'},
#  {'tag': 'img',
#   'metadata': {'depth': 3,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55137',
#    'node_type': None},
#   'src': 'welcome-to-nus/page_24_figure_686.png'},
#  {'tag': 'p',
#   'text': 'nus.edu.sg',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55138',
#    'node_type': None,
#    'original_index': 687,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'paragraph',
#    'page_number': 23,
#    'bbox': [811.0, 511.5, 850.5, 521.5],
#    'heading_level': None},
#   'data-page': '23'},
#  {'tag': 'figure',
#   'metadata': {'depth': 2,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55139',
#    'node_type': None,
#    'original_index': 688,
#    'parent_chapter': 677,
#    'is_chapter_title': False,
#    'element_type': 'figure',
#    'page_number': 23,
#    'bbox': [751.0, 587.0, 855.5, 636.0],
#    'image_extracted': True,
#    'ai_description': 'Skipped (disabled or too small)'},
#   'children': [{'tag': 'img',
#     'metadata': {'depth': 3,
#      'page_id': None,
#      'global_id': 'doc_welcome-to-nus_55140',
#      'node_type': None},
#     'src': 'welcome-to-nus/page_24_figure_688.png'}],
#   'src': 'welcome-to-nus/page_24_figure_688.png',
#   'data-page': '23'},
#  {'tag': 'img',
#   'metadata': {'depth': 3,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55140',
#    'node_type': None},
#   'src': 'welcome-to-nus/page_24_figure_688.png'},
#  {'tag': 'p',
#   'text': 'Produced by NUS Ofice of University Communications Company Registration Number: 200604346E',
#   'metadata': {'depth': 1,
#    'page_id': None,
#    'global_id': 'doc_welcome-to-nus_55141',
#    'node_type': None,
#    'original_index': 689,
#    'parent_chapter': -1,
#    'is_chapter_title': False,
#    'element_type': 'paragraph',
#    'page_number': 23,
#    'bbox': [670.0, 645.0, 853.5, 667.5],
#    'heading_level': None},
#   'data-page': '23'}]

# %%
print("版本信息:")
import torch, transformers
print(f"PyTorch: {torch.__version__}")
print(f"Transformers: {transformers.__version__}")

embedder = SubtreeEmbedder(
    text_model="openai/clip-vit-base-patch32",      # 使用CLIP处理文本
    image_model="openai/clip-vit-base-patch32",     # 使用CLIP处理图像  
    table_model="openai/clip-vit-base-patch32",     # 使用CLIP处理表格
    aggregator="attention",
    embedding_dim=512,  # CLIP base的维度
    data_dir="./data/dom/MMLongBench-Doc"
)

print("✅ SubtreeEmbedder初始化成功（使用CLIP模型）")
# Out:
# 版本信息:
# PyTorch: 2.0.1
# Transformers: 4.28.0
# ✅ SubtreeEmbedder初始化成功（使用CLIP模型）

# %% [markdown]
# # Table Embedding Test

# %%
# 查找包含table子节点的节点
for i in range(len(nodes)):
    # 对于字典格式的节点
    if isinstance(nodes[i], dict):
        children = nodes[i].get('children', [])
        if children:
            if children[0].get('tag') == 'table':
                print(i, nodes[i].get('tag'))
    # 对于DOMNode对象
    elif hasattr(nodes[i], 'children'):
        if nodes[i].children:
            if nodes[i].children[0].tag == 'table':
                print(i, nodes[i].tag)

# 显示第一个找到的节点信息
if len(nodes) > 0:
    node = nodes[0]
    if isinstance(node, dict):
        print(f"\n节点示例 (dict): {node.get('tag')} - ID: {node.get('metadata', {}).get('global_id')}")
        print(f"子节点数量: {len(node.get('children', []))}")
    else:
        print(f"\n节点示例 (DOMNode): {node.tag} - ID: {node.metadata.get('global_id')}")
        print(f"子节点数量: {len(node.children) if hasattr(node, 'children') else 0}")
# Out:
# 12 h1
# 456 h3
# 468 h2
# 480 h2
# 492 h4
# 504 h6
# 520 h2
#
# 节点示例 (dict): document - ID: doc_welcome-to-nus_54388
# 子节点数量: 12

# %%
nodes[456]
# Out:
# {'tag': 'h3',
#  'text': 'Above Central Forum',
#  'metadata': {'depth': 5,
#   'page_id': None,
#   'global_id': 'doc_welcome-to-nus_54844',
#   'node_type': None,
#   'original_index': 458,
#   'parent_chapter': 457,
#   'is_chapter_title': True,
#   'element_type': 'paragraph',
#   'page_number': 19,
#   'bbox': [471.0, 361.5, 559.0, 372.0],
#   'heading_level': 3},
#  'children': [{'tag': 'table',
#    'metadata': {'depth': 6,
#     'page_id': None,
#     'global_id': 'doc_welcome-to-nus_54845',
#     'node_type': None,
#     'original_index': 459,
#     'parent_chapter': 458,
#     'is_chapter_title': False,
#     'element_type': 'table',
#     'page_number': 19,
#     'bbox': [471.0, 375.0, 585.5, 411.0],
#     'table_image_extracted': True},
#    'children': [{'tag': 'tr',
#      'metadata': {'depth': 7,
#       'page_id': None,
#       'global_id': 'doc_welcome-to-nus_54846',
#       'node_type': None},
#      'children': [{'tag': 'td',
#        'text': 'Mon - Fri:',
#        'metadata': {'depth': 8,
#         'page_id': None,
#         'global_id': 'doc_welcome-to-nus_54847',
#         'node_type': None}},
#       {'tag': 'td',
#        'text': '8.30am to 9pm',
#        'metadata': {'depth': 8,
#         'page_id': None,
#         'global_id': 'doc_welcome-to-nus_54848',
#         'node_type': None}}]},
#     {'tag': 'tr',
#      'metadata': {'depth': 7,
#       'page_id': None,
#       'global_id': 'doc_welcome-to-nus_54849',
#       'node_type': None},
#      'children': [{'tag': 'td',
#        'text': 'Sat:',
#        'metadata': {'depth': 8,
#         'page_id': None,
#         'global_id': 'doc_welcome-to-nus_54850',
#         'node_type': None}},
#       {'tag': 'td',
#        'text': '10am to 5pm',
#        'metadata': {'depth': 8,
#         'page_id': None,
#         'global_id': 'doc_welcome-to-nus_54851',
#         'node_type': None}}]},
#     {'tag': 'tr',
#      'metadata': {'depth': 7,
#       'page_id': None,
#       'global_id': 'doc_welcome-to-nus_54852',
#       'node_type': None},
#      'children': [{'tag': 'td',
#        'text': 'Sun:',
#        'metadata': {'depth': 8,
#         'page_id': None,
#         'global_id': 'doc_welcome-to-nus_54853',
#         'node_type': None}},
#       {'tag': 'td',
#        'text': 'Closed',
#        'metadata': {'depth': 8,
#         'page_id': None,
#         'global_id': 'doc_welcome-to-nus_54854',
#         'node_type': None}}]}],
#    'src': 'welcome-to-nus/page_20_table_459.png',
#    'data-page': '19'}],
#  'data-page': '19'}

# %%
from subtree_embedding.encoders.table_encoder import TableEncoder

table_encoder = TableEncoder()

table_encoder.encode(nodes[12])
# Out:
# array([ 1.36678740e-01, -1.97675720e-01,  2.29415759e-01, -1.04295313e-01,
#         1.11870483e-01,  2.77452379e-01, -1.08328596e-01, -3.63796949e-03,
#        -7.39143789e-01,  1.86703846e-01, -4.06990111e-01,  7.04161078e-02,
#         1.08785309e-01,  2.61808395e-01,  1.11700848e-01, -2.73666948e-01,
#        -1.41534790e-01,  1.87388748e-01, -4.19057101e-01,  1.44080848e-01,
#         2.52538919e-01, -1.65698707e-01, -7.94518813e-02, -8.57548341e-02,
#         2.86377341e-01, -3.90812531e-02,  2.52067983e-01,  8.44589472e-02,
#         2.16674000e-01,  1.42580554e-01, -2.64740121e-02, -1.69311777e-01,
#        -3.20319325e-01,  2.30296716e-01,  1.73440948e-02,  2.65066400e-02,
#         2.94519782e-01,  4.51322168e-01,  8.32410678e-02,  4.22740728e-01,
#         1.81463748e-01,  3.47602636e-01, -3.12060088e-01, -8.38188380e-02,
#        -3.31527919e-01,  1.25120297e-01, -2.38368064e-01, -1.65586382e-01,
#         4.29241240e-01, -1.19316019e-02, -2.40681767e-01, -1.34150147e-01],
#       dtype=float32)

# %% [markdown]
# **Table A: Residential Development Capacity and the Impact of Rezonings, by Borough (2003-2007)**
#
# |  | Residential Capacity, by Sq Ft (2003) | %Land Area Rezoned | Change in Residential Capacity, by Sq Ft (as of 2007) | %Capacity Change |
# |---|---|---|---|---|
# | The Bronx | 980,000,000 | 18.4% | 290,000 | 0.0% |
# | Brooklyn | 1,606,000,000 | 13.9% | 19,950,000 | 1.2% |
# | Manhattan | 1,466,000,000 | 5.3% | 34,150,000 | 2.3% |
# | Queens | 1,342,000,000 | 19.0% | 37,850,000 | 2.8% |
# | Staten Island | 435,000,000 | 22.9% | 5,980,000 | 1.4% |
# | NYC | 5,829,000,000 | 17.7% | 98,220,000 | 1.7% |

# %% [markdown]
# **Table B: Median Income for Census Tracts Where Rezoned Lots Were Located (2007 $)**
#
# | All Tracts in NYC | Tracts with Upzoned Lots* | Tracts with Downzoned Lots* | Tracts with Contextual-only Rezoned Lots* |
# |---|---|---|---|
# | $53,724 | $44,444 | $51,195 | $63,550 |
#
# **Table C: Median Homeownership Rate for Census Tracts Where Rezoned Lots Were Located (2000)**
#
# | All Tracts in NYC | Tracts with Upzoned Lots* | Tracts with Downzoned Lots* | Tracts with Contextual-only Rezoned Lots* |
# |---|---|---|---|
# | 44.8% | 30.8% | 35.7% | 63.5% |
#
# **Table D: Percent of Rezoned Lots Within 1/2 a Mile of a Rail Station Entrance (2007)**
#
# | All NYC Lots | Upzoned Lots | Downzoned Lots | Contextual-only Rezoned Lots |
# |---|---|---|---|
# | 49.5% | 73.4% | 58.9% | 29.0% |

# %% [markdown]
# # Image Embedding Test

# %%
for i in range(len(nodes)):
    if nodes[i]['tag'] == 'figure':
        print(i, nodes[i]['tag'])
# Out:
# 2 figure
# 4 figure
# 10 figure
# 31 figure
# 35 figure
# 37 figure
# 41 figure
# 50 figure
# 53 figure
# 55 figure
# 63 figure
# 168 figure
# 170 figure
# 177 figure
# 196 figure
# 198 figure
# 200 figure
# 202 figure
# 205 figure
# 216 figure
# 218 figure
# 222 figure
# 226 figure
# 228 figure
# 230 figure
# 232 figure
# 234 figure
# 240 figure
# 259 figure
# 266 figure
# 271 figure
# 275 figure
# 290 figure
# 303 figure
# 320 figure
# 323 figure
# 329 figure
# 337 figure
# 339 figure
# 351 figure
# 353 figure
# 359 figure
# 363 figure
# 368 figure
# 372 figure
# 377 figure
# 381 figure
# 383 figure
# 389 figure
# 392 figure
# 399 figure
# 406 figure
# 414 figure
# 417 figure
# 419 figure
# 450 figure
# 452 figure
# 625 figure
# 633 figure
# 635 figure
# 672 figure
# 714 figure
# 716 figure
# 734 figure
# 737 figure
# 740 figure
# 746 figure
# 748 figure
# 751 figure

# %%
nodes[10]
# Out:
# {'tag': 'figure',
#  'metadata': {'depth': 2,
#   'page_id': None,
#   'global_id': 'doc_welcome-to-nus_54398',
#   'node_type': None,
#   'original_index': 7,
#   'parent_chapter': 5,
#   'is_chapter_title': False,
#   'element_type': 'figure',
#   'page_number': 1,
#   'bbox': [453.5, 15.0, 863.5, 493.5],
#   'image_extracted': True,
#   'description_method': 'full_page_region',
#   'ai_description': '**Summary**: The target region contains a large image of a building with a sign that reads "Welcome to NUS" and a contents page listing topics and page numbers.\n\n**Content Details**:\n- **Image**: A large, colorful photograph of a building with a prominent sign that says "Welcome to NUS" and includes the hashtag "#NUSBeyond".\n- **Contents Page**: A list of topics and corresponding page numbers, organized into sections such as "Starting Out", "Beyond the Classroom", and "Explore Campus Life".\n\n**Visual Features**:\n- **Colors**: Predominantly blue, green, and white, with a mix of text and graphics.\n- **Layout**: The contents page is structured with clear headings and a grid-like layout, making it easy to navigate.\n- **Text**: The text is in a readable font, with headings in a larger, bold font and subheadings in a smaller font.\n\n**Context Integration**:\n- The image and contents page are part of a student guide, likely for the National University of Singapore (NUS), given the "Welcome to NUS" sign.\n- The contents page provides an overview of what topics are covered in the guide, helping students find relevant information quickly.\n\n**Purpose**:\n- The image serves as a visual introduction to the university, setting a welcoming tone.\n- The contents page acts as a table of contents, guiding students to the specific information they need about living, learning, and thriving at NUS.'},
#  'children': [{'tag': 'img',
#    'metadata': {'depth': 3,
#     'page_id': None,
#     'global_id': 'doc_welcome-to-nus_54399',
#     'node_type': None},
#    'src': 'welcome-to-nus/page_2_figure_7.png'}],
#  'src': 'welcome-to-nus/page_2_figure_7.png',
#  'data-page': '1'}

# %%
from subtree_embedding.encoders.image_encoder import ImageEncoder

image_encoder = ImageEncoder(target_dim=512)

image_encoder.encode(nodes[10])
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# array([ 0.3235734 ,  0.51576835, -0.41412336,  0.22816797, -0.5063931 ,
#        -0.4346049 , -0.20765573, -0.24436751,  0.48946714, -0.21604484,
#        -0.07091527,  0.6570646 ,  0.479587  ,  0.66842496, -0.25481766,
#        -0.6063508 ,  0.28039005,  0.95903325, -0.52624774,  0.5016964 ,
#         0.41765702, -0.32217687, -0.30804425,  0.16458586, -0.07625186,
#         0.00444254,  0.40553138, -0.0676101 ,  0.5595541 , -0.8611907 ,
#        -0.07200384, -0.4215448 , -0.8455942 ,  0.6809541 ,  0.6608311 ,
#         0.18244106,  0.30533355, -0.10401656,  0.47927403,  0.28986022,
#         0.13490957,  1.0650345 , -0.09378101,  0.532217  ,  0.7327664 ,
#         0.05364907, -0.05372482,  0.02380083, -0.13743807, -0.359785  ,
#         0.00247374, -0.20142879,  0.00928274,  0.23888338, -0.32948104,
#        -0.10848442, -0.5623503 , -0.40181008, -0.0454251 ,  0.45871753,
#        -0.51603085, -0.35757887, -0.5901887 ,  1.3659723 , -0.13700546,
#        -0.14766   , -0.46840006, -0.3142581 , -0.42082337,  0.17357153,
#         0.06827672,  0.47979662, -0.7083674 , -0.2051172 ,  0.45989788,
#         0.29231417, -0.7314968 , -0.04826738,  0.66818756, -0.7455511 ,
#        -0.00166742,  1.0011073 ,  0.52560186, -0.5465975 ,  0.15627933,
#         0.21341309,  0.04045999,  0.06881841,  0.34127933,  0.1531572 ,
#         0.72526205,  0.298275  ,  0.15037611,  0.08492   ,  0.15401794,
#        -0.26402742, -0.30579334,  0.26497215, -0.3001202 ,  0.2019049 ,
#         0.6582868 ,  0.4945464 , -0.50900286,  0.13372937,  0.2721598 ,
#         1.6492199 ,  0.39193124, -0.08902164,  0.13162804, -0.18401656,
#         0.20699984,  0.49628603, -0.6781745 , -0.5959068 ,  0.20246717,
#         0.53595096,  0.5899552 ,  0.47510922, -0.71254724,  0.48254132,
#         0.15812299, -0.42456338,  0.24909241,  0.79239184,  0.20445901,
#        -0.09533498, -0.18891746], dtype=float32)

# %%
class QuestionEmbedder:
    """专门用于问题嵌入的类"""

    def __init__(self, model_name="openai/clip-vit-base-patch32", embedding_dim=512):
        """
        初始化问题嵌入器
        
        Args:
            model_name: 使用的模型名称
            embedding_dim: 嵌入维度
        """
        self.model_name = model_name
        self.embedding_dim = embedding_dim

        # 导入CLIP模型
        from transformers import CLIPModel, CLIPProcessor
        import torch

        print(f"加载CLIP模型: {model_name}")
        self.clip_model = CLIPModel.from_pretrained(model_name)
        self.clip_processor = CLIPProcessor.from_pretrained(model_name)

        # 设置为评估模式
        self.clip_model.eval()

        print(f"✅ QuestionEmbedder初始化成功，维度: {embedding_dim}")

    def embed_text(self, text):
        """
        对文本进行嵌入
        
        Args:
            text: 输入文本
            
        Returns:
            numpy.ndarray: 嵌入向量
        """
        import torch
        import numpy as np

        try:
            # 使用CLIP处理器处理文本
            inputs = self.clip_processor(text=[text], return_tensors="pt", padding=True, truncation=True)

            # 获取文本嵌入
            with torch.no_grad():
                text_features = self.clip_model.get_text_features(**inputs)

            # 转换为numpy数组并归一化
            embedding = text_features.squeeze().numpy()
            embedding = embedding / np.linalg.norm(embedding)  # L2归一化

            return embedding

        except Exception as e:
            print(f"文本嵌入失败: {e}")
            return None

    def embed_questions(self, questions):
        """
        批量嵌入多个问题
        
        Args:
            questions: 问题列表
            
        Returns:
            dict: {问题: 嵌入向量}
        """
        results = {}

        print(f"批量嵌入 {len(questions)} 个问题...")

        for i, question in enumerate(questions):
            print(f"处理问题 {i+1}/{len(questions)}: {question[:50]}...")

            embedding = self.embed_text(question)
            if embedding is not None:
                results[question] = embedding
                print(f"  ✅ 成功，维度: {embedding.shape}")
            else:
                print(f"  ❌ 失败")

        print(f"✅ 成功嵌入 {len(results)}/{len(questions)} 个问题")
        return results

    def similarity(self, query_embedding, doc_embedding):
        """
        计算两个嵌入向量的余弦相似度
        
        Args:
            query_embedding: 查询嵌入
            doc_embedding: 文档嵌入
            
        Returns:
            float: 相似度分数 (0-1)
        """
        import numpy as np

        # 确保向量是归一化的
        query_norm = query_embedding / np.linalg.norm(query_embedding)
        doc_norm = doc_embedding / np.linalg.norm(doc_embedding)

        # 计算余弦相似度
        similarity = np.dot(query_norm, doc_norm)
        return float(similarity)
 
 
question_embedder = QuestionEmbedder(
    model_name="openai/clip-vit-base-patch32",
    embedding_dim=512
)

def embed(text):
    return question_embedder.embed_text(text)

  # 使用
q = embed("welcome NUS")

question_embedder.similarity(q, image_encoder.encode(nodes[10]))
# Out:
# 加载CLIP模型: openai/clip-vit-base-patch32
# ✅ QuestionEmbedder初始化成功，维度: 512
# 0.04266424849629402

# %%
# 1. 测试文本自相似度
q1 = embed("welcome to NUS")
q2 = embed("welcome to NUS")
print(f"文本自相似度: {question_embedder.similarity(q1, q2)}")  # 应该是1.0

# 2. 创建512维的问题编码器来匹配图像编码器
question_embedder_512 = QuestionEmbedder(
    model_name="openai/clip-vit-base-patch32",
    embedding_dim=512  # 使用原始维度
)

def embed_512(text):
    return question_embedder_512.embed_text(text)

# 3. 用匹配的维度测试
q_512 = embed_512("welcome to NUS")
img_emb = image_encoder.encode(nodes[10])

print(f"Query 512维: {q_512.shape}")
print(f"Image 512维: {img_emb.shape}")
print(f"正确维度相似度: {question_embedder_512.similarity(q_512, img_emb)}")

# 4. 测试AI描述的相似度
ai_desc = nodes[10]['metadata']['ai_description']
q_desc = embed_512(ai_desc)
print(f"AI描述相似度: {question_embedder_512.similarity(q_desc, img_emb)}")
# Out:
# 文本自相似度: 1.0
# 加载CLIP模型: openai/clip-vit-base-patch32
# ✅ QuestionEmbedder初始化成功，维度: 512
# Query 512维: (512,)
# Image 512维: (512,)
# 正确维度相似度: 0.044546037912368774
# AI描述相似度: 0.005650727078318596

# %%
ai_desc = nodes[10].get('metadata', {}).get('ai_description', '')
print(ai_desc)
q_ai = embed_512(ai_desc)
print(f"完整AI描述相似度: {question_embedder_512.similarity(q_512, q_ai)}")
# Out:
# **Summary**: The target region contains a large image of a building with a sign that reads "Welcome to NUS" and a contents page listing topics and page numbers.
#
# **Content Details**:
# - **Image**: A large, colorful photograph of a building with a prominent sign that says "Welcome to NUS" and includes the hashtag "#NUSBeyond".
# - **Contents Page**: A list of topics and corresponding page numbers, organized into sections such as "Starting Out", "Beyond the Classroom", and "Explore Campus Life".
#
# **Visual Features**:
# - **Colors**: Predominantly blue, green, and white, with a mix of text and graphics.
# - **Layout**: The contents page is structured with clear headings and a grid-like layout, making it easy to navigate.
# - **Text**: The text is in a readable font, with headings in a larger, bold font and subheadings in a smaller font.
#
# **Context Integration**:
# - The image and contents page are part of a student guide, likely for the National University of Singapore (NUS), given the "Welcome to NUS" sign.
# - The contents page provides an overview of what topics are covered in the guide, helping students find relevant information quickly.
#
# **Purpose**:
# - The image serves as a visual introduction to the university, setting a welcoming tone.
# - The contents page acts as a table of contents, guiding students to the specific information they need about living, learning, and thriving at NUS.
# 完整AI描述相似度: 0.6070554852485657

# %%
visual_only = image_encoder._encode_visual_content(nodes[10])
print(f"纯视觉特征相似度: {question_embedder_512.similarity(q_512, visual_only)}")
# Out:
# 纯视觉特征相似度: 0.048249751329422

# %%
q_combined = embed_512("a large image of a building with a sign that reads \Welcome to NUS\ ")
print(f"组合查询相似度: {question_embedder_512.similarity(q_combined, img_emb)}")
# Out:
# 组合查询相似度: 0.027539867907762527

# %%
def debug_multimodal_similarity():
    img_node = nodes[10]

    # 1. 分析图像节点的实际内容
    print("=== 图像节点分析 ===")
    ai_desc = img_node.get('metadata', {}).get('ai_description', '')
    print(f"AI描述: {ai_desc[:200]}...")

    # 2. 分别测试各个组件
    print("\n=== 组件分析 ===")

    # 图像的视觉特征
    visual_feat = image_encoder._encode_visual_content(img_node)
    print(f"视觉特征形状: {visual_feat.shape}")
    print(f"视觉特征非零: {np.count_nonzero(visual_feat)}")

    # 图像的文本特征  
    text_feat = image_encoder._encode_text_context(img_node)
    print(f"文本特征形状: {text_feat.shape}")
    print(f"文本特征非零: {np.count_nonzero(text_feat)}")

    # 融合后的特征
    fused_feat = image_encoder._fuse_features(visual_feat, text_feat, img_node)
    print(f"融合特征形状: {fused_feat.shape}")

    # 3. 测试不同的查询方式
    print("\n=== 查询测试 ===")

    # 原始查询
    q1 = embed_512("welcome to NUS")
    sim1 = question_embedder_512.similarity(q1, text_feat)  # 只与文本部分比较
    print(f"与文本特征相似度: {sim1:.3f}")

    # 直接用AI描述文本测试
    q2 = embed_512("Welcome to NUS building with sign and contents page")
    sim2 = question_embedder_512.similarity(q2, text_feat)
    print(f"扩展描述相似度: {sim2:.3f}")

    # 测试AI描述的自相似度
    ai_emb = embed_512(ai_desc)
    sim3 = question_embedder_512.similarity(ai_emb, text_feat)
    print(f"AI描述自相似度: {sim3:.3f}")

    # 4. 检查image_encoder的文本编码逻辑
    print("\n=== 文本编码调试 ===")
    query_node = {
        'tag': 'query',
        'text': "welcome to NUS",
        'metadata': {
            'ai_description': "welcome to NUS",
            'element_type': 'query'
        }
    }

    query_text_feat = image_encoder._encode_text_context(query_node)
    print(f"查询文本特征非零: {np.count_nonzero(query_text_feat)}")

    # 直接相似度
    sim4 = question_embedder_512.similarity(query_text_feat, text_feat)
    print(f"查询文本特征相似度: {sim4:.3f}")

debug_multimodal_similarity()
# Out:
# === 图像节点分析 ===
# AI描述: **Summary**: The target region contains a large image of a building with a sign that reads "Welcome to NUS" and a contents page listing topics and page numbers.
#
# **Content Details**:
# - **Image**: A la...
#
# === 组件分析 ===
# 视觉特征形状: (512,)
# 视觉特征非零: 512
# 文本特征形状: (512,)
# 文本特征非零: 512
# 融合特征形状: (512,)
#
# === 查询测试 ===
# 与文本特征相似度: 0.000
# 扩展描述相似度: 0.019
# AI描述自相似度: 0.010
#
# === 文本编码调试 ===
# 查询文本特征非零: 512
# 查询文本特征相似度: 0.653

# %%
def embed_query_multimodal(text):
    # 将查询文本也处理成类似image_encoder的格式
    query_node = {
        'tag': 'query',
        'text': text,
        'metadata': {
            'ai_description': text,  # 把查询当作AI描述
            'element_type': 'query'
        }
    }

    # 使用image_encoder的文本编码部分
    text_features = image_encoder._encode_text_context(query_node)
    return text_features

# 测试
q_multimodal = embed_query_multimodal("a large image of a building with a sign that reads \Welcome to NUS\ ")
sim = question_embedder_512.similarity(q_multimodal, img_emb)
print(f"多模态查询相似度: {sim}")
# Out:
# 多模态查询相似度: 0.2818060517311096

# %% [markdown]
# # Parent node

# %%
nodes[49].to_json_dict()
# Out:
# {'tag': 'figure',
#  'metadata': {'depth': 2,
#   'page_id': '4',
#   'global_id': 'node_2480',
#   'node_type': None},
#  'children': [{'tag': 'img',
#    'metadata': {'depth': 3,
#     'page_id': '4',
#     'global_id': 'node_2481',
#     'node_type': 'image'},
#    'src': '8e7c4cb542ad160f80fb3d795ada35d8_with_image_refs_artifacts/image_000008_8133ff07a71d435f8c68b19de73ce3839fdbd04eddf043e65935d2d1a10d880a.png'}]}

# %%
embedding_result = embedder.encode_subtree(nodes[54], max_depth=3)
# Out:
# Encoding internal node - type: list, children: 3
# Encoding leaf node - type: list
# Encoding leaf node - type: list
# Encoding leaf node - type: list

# %%
embedding_result.keys()
embedding_result
# Out:
# {'embedding': array([-7.09770247e-03, -1.31934620e-02, -1.55713968e-02, -1.99010447e-02,
#         -2.04501674e-04,  1.88648067e-02,  1.67484917e-02, -9.70853306e-03,
#          1.44703127e-03, -2.65601687e-02, -4.41717282e-02, -9.86607466e-03,
#          1.95105635e-02, -2.29470897e-03, -1.89260952e-02, -1.54101476e-02,
#          1.28739709e-02, -2.00524926e-04,  3.46677890e-03,  2.38932781e-02,
#          1.34883262e-02,  3.53751006e-03,  8.07017647e-03,  3.73703940e-03,
#          1.26829315e-02,  1.07490346e-02,  2.95155719e-02, -4.19999510e-02,
#         -3.52409994e-03,  6.44208863e-03,  3.63410115e-02,  2.45656222e-02,
#          3.73080522e-02, -3.97562124e-02,  8.55441578e-03,  1.72785148e-02,
#         -5.64225670e-03,  1.35858171e-03,  1.52265327e-02, -3.10858954e-02,
#          1.23050045e-02, -3.34948674e-03, -3.32341902e-03, -1.40123442e-02,
#          5.84061816e-03,  1.40357893e-02,  1.35233290e-02,  1.74291078e-02,
#         -9.00099333e-03, -3.13648023e-04,  2.90256217e-02, -2.94006579e-02,
#         -1.29325902e-02,  3.82712707e-02,  6.50199968e-03, -7.99411163e-03,
#          2.82713436e-02,  1.56712849e-02, -9.49636661e-03,  5.96795790e-03,
#         -2.41205804e-02,  1.16448384e-04,  3.01723517e-02,  7.11645372e-03,
#         -1.46092167e-02,  1.47408657e-02,  2.09744610e-02, -3.75870941e-03,
#          7.46618072e-03, -4.11052927e-02,  5.70749398e-03,  1.53883025e-02,
#          2.32361387e-02, -1.64926723e-02,  6.78310636e-03, -7.63476454e-03,
#         -7.07805902e-03, -1.47867845e-02, -6.91634510e-03,  4.61877882e-02,
    text="1  The 'one-fifth' calculation excludes the City's park land. See press release, celebrating the 100th rezoning for more detail: http://nyc.gov/html/dcp/html/about/pr102809.shtml.", 
    attributes={}, 
    children=[
        DOMNode(
            tag='text', 
            text="1  The 'one-fifth' calculation excludes the City's park land. See press release, celebrating the 100th rezoning for more detail: http://nyc.gov/html/dcp/html/about/pr102809.shtml.", 
            attributes={}, 
            children=[], 
            position={'order': 0}, 
            node_type='text', 
            metadata={'page_number': '1', 'global_id': 'text_9'}
            )
            ], 
    position={'order': 17},
    node_type='text', 
    metadata={'page_number': '1', 'global_id': 'text_10'}
    ), 

DOMNode(
    tag='text', 
    text="1  The 'one-fifth' calculation excludes the City's park land. See press release, celebrating the 100th rezoning for more detail: http://nyc.gov/html/dcp/html/about/pr102809.shtml.", 
    attributes={}, 
    children=[], 
    position={'order': 0}, 
    node_type='text', 
    metadata={'page_number': '1', 'global_id': 'text_9'})
# Out:
# DOMNode(tag='text', text="1  The 'one-fifth' calculation excludes the City's park land. See press release, celebrating the 100th rezoning for more detail: http://nyc.gov/html/dcp/html/about/pr102809.shtml.", attributes={}, children=[], position={'order': 0}, node_type='text', metadata={'page_number': '1', 'global_id': 'text_9'})

# %%
import sys
import os
import pickle
from dataclasses import dataclass, asdict
import json
import numpy as np
from typing import Dict, List, Any, Optional, Tuple
import logging
from pathlib import Path
from tqdm import tqdm
import hashlib
# 添加项目根目录到路径
current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
project_root = os.path.dirname(current_dir)  # 上一级目录就是项目根目录
sys.path.append(project_root)
from subtree_embedding import SubtreeEmbedder
from src.core.dom_processor_v2 import TokenAwareDOMProcessor, DOMNode
# from dom_tree.builder import build_tree_json_object, build_global_tree_from_html
# from dom_tree.node import DOMNode

@dataclass
class EmbeddingResult:
    """嵌入结果的数据结构"""
    node_id: str
    embedding: np.ndarray
    metadata: Dict[str, Any]
    structure_info: Dict[str, Any]
    parent_id: Optional[str] = None
    children_ids: List[str] = None
    embedding_time: float = 0.0

config = {
        'text_model': 'BAAI/bge-large-en-v1.5',
        'image_model': 'openai/clip-vit-base-patch32',
        'table_model': 'microsoft/tapex-base',
        'aggregator': 'attention',
        'embedding_dim': 768,
        'pruning': {
            'tag_blacklist': ['script', 'style'],
            'max_tokens_per_chunk': 2000
        }
    }

dom_processor = TokenAwareDOMProcessor(config)

# %%
def _collect_all_nodes(root_node: DOMNode) -> List[DOMNode]:
    """收集DOM树中的所有节点"""
    nodes = []
        
    def dfs_collect(node: DOMNode):
        # 只处理有全局ID的节点
        if hasattr(node, 'metadata') and node.metadata.get('global_id'):
                nodes.append(node)
            
        # 递归处理子节点
        if hasattr(node, 'children'):
            for child in node.children:
                dfs_collect(child)
        
    dfs_collect(root_node)
    return nodes

html_file_path = './testdata/8e7c4cb542ad160f80fb3d795ada35d8.html'
tree, chunks, process_logs = dom_processor.process_html_file(html_file_path)
# tree = build_global_tree_from_html(html_file_path)
        
nodes = _collect_all_nodes(root_node = tree)

tree
# Out:
# 🔍 发现表格标题: 行0 - Table B: Median Income for Census Tracts Where Rezoned Lots Were Located (2007 $)
# 🔍 发现表格标题: 行3 - Table C: Median Homeownership Rate for Census Tracts Where Rezoned Lots Were Located (2000)
# 🔍 发现表格标题: 行6 - Table D: Percent of Rezoned Lots Within 1/2 a Mile of a Rail Station Entrance (2007)
# 🔧 拆分复合表格: 发现 3 个逻辑表格
#    ✅ 创建逻辑表格 1: table_2 - Table B: Median Income for Census Tracts Where Rezoned Lots Were Located (2007 $)
#    ✅ 创建逻辑表格 2: table_3 - Table C: Median Homeownership Rate for Census Tracts Where Rezoned Lots Were Located (2000)
#    ✅ 创建逻辑表格 3: table_4 - Table D: Percent of Rezoned Lots Within 1/2 a Mile of a Rail Station Entrance (2007)
#    📦 创建包装节点，包含 3 个拆分表格
# collapsed: <class 'src.core.dom_processor_v2.DOMNode'>
# Collapsed DOM saved to: data/collapsed/8e7c4cb542ad160f80fb3d795ada35d8_collapsed.json
# DOMNode(tag='div', text='', attributes={'class': 'single-column'}, children=[DOMNode(tag='div', text='', attributes={'class': 'page', 'data-page': '1'}, children=[DOMNode(tag='figure', text='', attributes={}, children=[DOMNode(tag='img', text='', attributes={'src': '8e7c4cb542ad160f80fb3d795ada35d8_artifacts/image_000000_792fdace62b55a9af3fd93e661c187ae595f6c66aac3ec49f73493757b3e9753.png'}, children=[], position={'order': 0}, node_type='image', metadata={'page_number': '1', 'caption': '', 'alt': '', 'title': '', 'global_id': 'image_1'})], position={'order': 3}, node_type='image_container', metadata={'page_number': '1', 'global_id': 'image_container_1'}), DOMNode(tag='figure', text='', attributes={}, children=[DOMNode(tag='img', text='', attributes={'src': '8e7c4cb542ad160f80fb3d795ada35d8_artifacts/image_000001_fc3078cd1bac1b659228b8b84c56fc1a55e52888b66c92d38c62522d6d953c6c.png'}, children=[], position={'order': 0}, node_type='image', metadata={'page_number': '1', 'caption': '', 'alt': '', 'title': '', 'global_id': 'image_2'})], position={'order': 5}, node_type='image_container', metadata={'page_number': '1', 'global_id': 'image_container_2'}), DOMNode(tag='figure', text='', attributes={}, children=[DOMNode(tag='img', text='', attributes={'src': '8e7c4cb542ad160f80fb3d795ada35d8_artifacts/image_000002_1f6ea6edd47a8f736f04619eedd768f0a6c412b16f3e75e092b2b6dd8d5d1c4a.png'}, children=[], position={'order': 0}, node_type='image', metadata={'page_number': '1', 'caption': '', 'alt': '', 'title': '', 'global_id': 'image_3'})], position={'order': 7}, node_type='image_container', metadata={'page_number': '1', 'global_id': 'image_container_3'}), DOMNode(tag='h2', text='P O L I C Y   B R I E F', attributes={}, children=[DOMNode(tag='text', text='P O L I C Y   B R I E F', attributes={}, children=[], position={'order': 0}, node_type='text', metadata={'page_number': '1', 'global_id': 'text_3'})], position={'order': 9}, node_type='heading', metadata={'page_number': '1', 'global_id': 'heading_1'}), DOMNode(tag='h2', text="How Have Recent Rezonings Affected the City's Ability to Grow?", attributes={}, children=[DOMNode(tag='text', text="How Have Recent Rezonings Affected the City's Ability to Grow?", attributes={}, children=[], position={'order': 0}, node_type='text', metadata={'page_number': '1', 'global_id': 'text_4'})], position={'order': 11}, node_type='heading', metadata={'page_number': '1', 'global_id': 'heading_2'}), DOMNode(tag='p', text="In  October  2009,  the  Bloomberg  Administration celebrated its 100th rezoning, a significant milestone for a massive and unprecedented rezoning agenda that has affected more  than  one-fifth  of  the  City  and  has significant implications for the City's development landscape. 1 These rezonings reflect a wide range of goals: advancing the City's economic development agenda; accommodating expected population growth (PlanNYC 2030 estimates the City will grow by  one  million  new  New  Yorkers  by  2030 over  its  2000  population);  and  responding to the varied needs and preferences of the City's diverse neighborhoods.", attributes={}, children=[DOMNode(tag='text', text="In  October  2009,  the  Bloomberg  Administration celebrated its 100th rezoning, a significant milestone for a massive and unprecedented rezoning agenda that has affected more  than  one-fifth  of  the  City  and  has significant implications for the City's development landscape. 1 These rezonings reflect a wide range of goals: advancing the City's economic development agenda; accommodating expected population growth (PlanNYC 2030 estimates the City will grow by  one  million  new  New  Yorkers  by  2030 over  its  2000  population);  and  responding to the varied needs and preferences of the City's diverse neighborhoods.", attributes={}, children=[], position={'order': 0}, node_type='text', metadata={'page_number': '1', 'global_id': 'text_5'})], position={'order': 13}, node_type='text', metadata={'page_number': '1', 'global_id ...

# %%
nodes[2]
# Out:
# {'tag': 'figure',
#  'text': 'NUS National University of Singapore',
#  'metadata': {'depth': 1,
#   'page_id': None,
#   'global_id': 'doc_welcome-to-nus_54390',
#   'node_type': None,
#   'original_index': 1,
#   'parent_chapter': -1,
#   'is_chapter_title': False,
#   'element_type': 'figure',
#   'page_number': 0,
#   'bbox': [22.5, 334.0, 111.5, 379.5],
#   'image_extracted': True,
#   'ai_description': 'Skipped (disabled or too small)'},
#  'children': [{'tag': 'img',
#    'metadata': {'depth': 2,
#     'page_id': None,
#     'global_id': 'doc_welcome-to-nus_54391',
#     'node_type': None},
#    'src': 'welcome-to-nus/page_1_figure_1.png'}],
#  'src': 'welcome-to-nus/page_1_figure_1.png',
#  'data-page': '0'}

# %%
from subtree_embedding.utils import NodeTypeClassifier
from json_to_dom_processor import DOMNode
import json

# 创建分类器实例
classifier = NodeTypeClassifier()

def classify_all_nodes(node_dict):
    result = classifier.classify(node_dict)
    print(f"Node {node_dict['tag']} classified as: {result}")

    # 递归处理子节点
    for child_dict in node_dict.get('children', []):
        classify_all_nodes(child_dict)

with open("./data/dom/MMLongBench-Doc/welcome-to-nus.json", "r") as f:
    tree_data = json.load(f)

# 直接传入字典数据，不需要转换为 DOMNode
classify_all_nodes(tree_data)
# Out:
# Qwen2VL not available. Please install transformers and torch to use Qwen2VL.
# Node document classified as: None
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node p classified as: text
# Node h1 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h1 classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h1 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node h1 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node h2 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node td classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node footer classified as: text
# Node footer classified as: text
# Node h2 classified as: text
# Node h3 classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h1 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node h1 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h1 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h1 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node footer classified as: text
# Node footer classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h3 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h3 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node footer classified as: text
# Node footer classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h1 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node ul classified as: None
# Node h3 classified as: text
# Node ul classified as: None
# Node footer classified as: text
# Node footer classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node ul classified as: None
# Node ul classified as: None
# Node ul classified as: None
# Node ul classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node p classified as: text
# Node ul classified as: None
# Node footer classified as: text
# Node footer classified as: text
# Node p classified as: text
# Node ul classified as: None
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h4 classified as: text
# Node ul classified as: None
# Node h2 classified as: text
# Node h3 classified as: text
# Node ul classified as: None
# Node h3 classified as: text
# Node p classified as: text
# Node ul classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node ul classified as: None
# Node h2 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h3 classified as: text
# Node ul classified as: None
# Node h3 classified as: text
# Node ul classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h4 classified as: text
# Node ul classified as: None
# Node footer classified as: text
# Node footer classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h3 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h3 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h3 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node ul classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node ul classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node p classified as: text
# Node ul classified as: None
# Node footer classified as: text
# Node footer classified as: text
# Node h2 classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h1 classified as: text
# Node h3 classified as: text
# Node h5 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h2 classified as: text
# Node h1 classified as: text
# Node p classified as: text
# Node h1 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node h5 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node h5 classified as: text
# Node h3 classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node h2 classified as: text
# Node h2 classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node h3 classified as: text
# Node h2 classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node h4 classified as: text
# Node h4 classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node h4 classified as: text
# Node h6 classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node h2 classified as: text
# Node h5 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node h2 classified as: text
# Node table classified as: table
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node tr classified as: None
# Node td classified as: None
# Node td classified as: None
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node h1 classified as: text
# Node h2 classified as: text
# Node h3 classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h4 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h4 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h5 classified as: text
# Node h5 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h5 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h5 classified as: text
# Node h5 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h5 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node h1 classified as: text
# Node h2 classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node h3 classified as: text
# Node h4 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node h2 classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node h5 classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node h4 classified as: text
# Node h2 classified as: text
# Node h3 classified as: text
# Node h4 classified as: text
# Node h5 classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node h2 classified as: text
# Node p classified as: text
# Node h2 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node h4 classified as: text
# Node p classified as: text
# Node h3 classified as: text
# Node p classified as: text
# Node footer classified as: text
# Node footer classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node h1 classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text
# Node figure classified as: image
# Node img classified as: None
# Node p classified as: text

# %%
from subtree_embedding.utils import StructuralPromptGenerator
import json

# 创建生成器实例
structure = StructuralPromptGenerator()

def structure_all_nodes(node_dict, depth=0):
    result = structure.generate_prompt(node_dict, depth)  # 添加 depth 参数
    print(f"Node {node_dict['tag']} structure as: {result}")

    # 递归处理子节点，深度+1
    for child_dict in node_dict.get('children', []):
        structure_all_nodes(child_dict, depth + 1)

with open("./data/dom/MMLongBench-Doc/welcome-to-nus.json", "r") as f:
    tree_data = json.load(f)

# 直接传入字典数据，从深度0开始
structure_all_nodes(tree_data)
# Out:
# Node document structure as: :
# Node p structure as: [Page 1] [Depth 1] [Paragraph] [Pos: 604,21]:
# Node figure structure as: [Page 1] [Depth 1] [Figure] [Pos: 22,334]:
# Node img structure as: [Depth 2]:
# Node figure structure as: [Page 1] [Depth 1] [Figure] [Pos: 209,147]:
# Node img structure as: [Depth 2]:
# Node p structure as: [Page 1] [Depth 1] [Paragraph] [Pos: 473,622]:
# Node p structure as: [Page 1] [Depth 1] [Paragraph] [Pos: 473,640]:
# Node h1 structure as: [Page 1] [Depth 1] [Paragraph] [Pos: 473,650] [H1]:
# Node p structure as: [Page 1] [Depth 2] [Paragraph] [Pos: 784,628]:
# Node figure structure as: [Page 2] [Depth 2] [Figure] [Pos: 454,15]:
# Node img structure as: [Depth 3]:
# Node h1 structure as: [Page 2] [Depth 1] [Paragraph] [Pos: 476,508] [H1]:
# Node table structure as: [Page 2] [Depth 2] [Table] [Pos: 474,530]:
# Node tr structure as: [Depth 3]:
# Node td structure as: [Depth 4]:
# Node td structure as: [Depth 4]:
# Node td structure as: [Depth 4]:
# Node tr structure as: [Depth 3]:
# Node td structure as: [Depth 4]:
# Node td structure as: [Depth 4]:
# Node td structure as: [Depth 4]:
# Node tr structure as: [Depth 3]:
# Node td structure as: [Depth 4]:
# Node td structure as: [Depth 4]:
# Node td structure as: [Depth 4]:
# Node tr structure as: [Depth 3]:
# Node td structure as: [Depth 4]:
# Node td structure as: [Depth 4]:
# Node td structure as: [Depth 4]:
# Node p structure as: [Page 2] [Depth 2] [Paragraph] [Pos: 476,645]:
# Node figure structure as: [Page 3] [Depth 2] [Figure] [Pos: 19,0]:
# Node img structure as: [Depth 3]:
# Node h2 structure as: [Page 3] [Depth 1] [Paragraph] [Pos: 232,488] [H2]:
# Node p structure as: [Page 3] [Depth 2] [Paragraph] [Pos: 493,24]:
# Node figure structure as: [Page 3] [Depth 2] [Figure] [Pos: 472,22]:
# Node img structure as: [Depth 3]:
# Node figure structure as: [Page 3] [Depth 2] [Figure] [Pos: 660,6]:
# Node img structure as: [Depth 3]:
# Node p structure as: [Page 3] [Depth 2] [Paragraph] [Pos: 502,233]:
# Node p structure as: [Page 3] [Depth 2] [Paragraph] [Pos: 502,330]:
# Node figure structure as: [Page 3] [Depth 2] [Figure] [Pos: 459,442]:
# Node img structure as: [Depth 3]:
# Node h2 structure as: [Page 4] [Depth 2] [Paragraph] [Pos: 22,22] [H2]:
# Node h2 structure as: [Page 4] [Depth 3] [Paragraph] [Pos: 32,106] [H2]:
# Node p structure as: [Page 4] [Depth 4] [Paragraph] [Pos: 31,118]:
# Node p structure as: [Page 4] [Depth 4] [Paragraph] [Pos: 222,104]:
# Node p structure as: [Page 4] [Depth 4] [Paragraph] [Pos: 314,246]:
# Node h1 structure as: [Page 4] [Depth 3] [Paragraph] [Pos: 472,296] [H1]:
# Node p structure as: [Page 4] [Depth 4] [Paragraph] [Pos: 472,308]:
# Node figure structure as: [Page 4] [Depth 4] [Figure] [Pos: 470,476]:
# Node img structure as: [Depth 5]:
# Node p structure as: [Page 4] [Depth 4] [Paragraph] [Pos: 136,616]:
# Node figure structure as: [Page 4] [Depth 4] [Figure] [Pos: 468,28]:
# Node img structure as: [Depth 5]:
# Node figure structure as: [Page 4] [Depth 4] [Figure] [Pos: 628,292]:
# Node img structure as: [Depth 5]:
# Node h2 structure as: [Page 4] [Depth 3] [Paragraph] [Pos: 702,478] [H2]:
# Node p structure as: [Page 4] [Depth 4] [Paragraph] [Pos: 700,490]:
# Node footer structure as: [Page 4] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 4] [Depth 4] [Page_footer] [Pos: 831,663]:
# Node h1 structure as: [Page 5] [Depth 2] [Paragraph] [Pos: 28,33] [H1]:
# Node p structure as: [Page 5] [Depth 3] [Paragraph] [Pos: 33,100]:
# Node figure structure as: [Page 5] [Depth 3] [Figure] [Pos: 28,146]:
# Node img structure as: [Depth 4]:
# Node h2 structure as: [Page 5] [Depth 3] [Paragraph] [Pos: 492,98] [H2]:
# Node h2 structure as: [Page 5] [Depth 4] [Paragraph] [Pos: 503,111] [H2]:
# Node h2 structure as: [Page 5] [Depth 4] [Paragraph] [Pos: 511,124] [H2]:
# Node p structure as: [Page 5] [Depth 5] [Paragraph] [Pos: 612,137]:
# Node p structure as: [Page 5] [Depth 5] [Paragraph] [Pos: 492,136]:
# Node p structure as: [Page 5] [Depth 5] [Paragraph] [Pos: 621,150]:
# Node p structure as: [Page 5] [Depth 5] [Paragraph] [Pos: 630,163]:
# Node p structure as: [Page 5] [Depth 5] [Paragraph] [Pos: 757,176]:
# Node table structure as: [Page 5] [Depth 5] [Table] [Pos: 450,230]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node tr structure as: [Depth 6]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node td structure as: [Depth 7]:
# Node h2 structure as: [Page 5] [Depth 3] [Paragraph] [Pos: 472,562] [H2]:
# Node p structure as: [Page 5] [Depth 4] [Paragraph] [Pos: 778,586]:
# Node table structure as: [Page 5] [Depth 4] [Table] [Pos: 472,583]:
# Node tr structure as: [Depth 5]:
# Node td structure as: [Depth 6]:
# Node td structure as: [Depth 6]:
# Node tr structure as: [Depth 5]:
# Node td structure as: [Depth 6]:
# Node td structure as: [Depth 6]:
# Node tr structure as: [Depth 5]:
# Node td structure as: [Depth 6]:
# Node td structure as: [Depth 6]:
# Node tr structure as: [Depth 5]:
# Node td structure as: [Depth 6]:
# Node td structure as: [Depth 6]:
# Node tr structure as: [Depth 5]:
# Node td structure as: [Depth 6]:
# Node td structure as: [Depth 6]:
# Node footer structure as: [Page 5] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 5] [Depth 4] [Page_footer] [Pos: 831,663]:
# Node h2 structure as: [Page 6] [Depth 2] [Paragraph] [Pos: 32,30] [H2]:
# Node h3 structure as: [Page 6] [Depth 3] [Paragraph] [Pos: 33,106] [H3]:
# Node figure structure as: [Page 6] [Depth 4] [Figure] [Pos: 30,132]:
# Node img structure as: [Depth 5]:
# Node figure structure as: [Page 6] [Depth 4] [Figure] [Pos: 468,30]:
# Node img structure as: [Depth 5]:
# Node h2 structure as: [Page 6] [Depth 4] [Paragraph] [Pos: 472,258] [H2]:
# Node h2 structure as: [Page 6] [Depth 5] [Paragraph] [Pos: 472,280] [H2]:
# Node p structure as: [Page 6] [Depth 6] [Paragraph] [Pos: 472,292]:
# Node h1 structure as: [Page 6] [Depth 5] [Paragraph] [Pos: 472,384] [H1]:
# Node p structure as: [Page 6] [Depth 6] [Paragraph] [Pos: 472,396]:
# Node figure structure as: [Page 6] [Depth 6] [Figure] [Pos: 470,476]:
# Node img structure as: [Depth 7]:
# Node h2 structure as: [Page 6] [Depth 5] [Paragraph] [Pos: 666,278] [H2]:
# Node p structure as: [Page 6] [Depth 6] [Paragraph] [Pos: 666,292]:
# Node h1 structure as: [Page 6] [Depth 5] [Paragraph] [Pos: 666,369] [H1]:
# Node p structure as: [Page 6] [Depth 6] [Paragraph] [Pos: 666,382]:
# Node h2 structure as: [Page 6] [Depth 3] [Paragraph] [Pos: 710,478] [H2]:
# Node h4 structure as: [Page 6] [Depth 4] [Paragraph] [Pos: 710,500] [H4]:
# Node p structure as: [Page 6] [Depth 5] [Paragraph] [Pos: 709,512]:
# Node footer structure as: [Page 6] [Depth 5] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 6] [Depth 5] [Page_footer] [Pos: 831,663]:
# Node p structure as: [Page 7] [Depth 5] [Paragraph] [Pos: 32,30]:
# Node h2 structure as: [Page 7] [Depth 3] [Paragraph] [Pos: 33,106] [H2]:
# Node h1 structure as: [Page 7] [Depth 4] [Paragraph] [Pos: 32,134] [H1]:
# Node h4 structure as: [Page 7] [Depth 5] [Paragraph] [Pos: 33,156] [H4]:
# Node p structure as: [Page 7] [Depth 6] [Paragraph] [Pos: 32,168]:
# Node h2 structure as: [Page 7] [Depth 4] [Paragraph] [Pos: 32,220] [H2]:
# Node h2 structure as: [Page 7] [Depth 5] [Paragraph] [Pos: 33,242] [H2]:
# Node p structure as: [Page 7] [Depth 6] [Paragraph] [Pos: 33,256]:
# Node figure structure as: [Page 7] [Depth 6] [Figure] [Pos: 31,298]:
# Node img structure as: [Depth 7]:
# Node figure structure as: [Page 7] [Depth 6] [Figure] [Pos: 32,476]:
# Node img structure as: [Depth 7]:
# Node figure structure as: [Page 7] [Depth 6] [Figure] [Pos: 470,30]:
# Node img structure as: [Depth 7]:
# Node figure structure as: [Page 7] [Depth 6] [Figure] [Pos: 302,134]:
# Node img structure as: [Depth 7]:
# Node p structure as: [Page 7] [Depth 6] [Paragraph] [Pos: 258,196]:
# Node figure structure as: [Page 7] [Depth 6] [Figure] [Pos: 664,30]:
# Node img structure as: [Depth 7]:
# Node h1 structure as: [Page 7] [Depth 4] [Paragraph] [Pos: 472,180] [H1]:
# Node h3 structure as: [Page 7] [Depth 5] [Paragraph] [Pos: 472,202] [H3]:
# Node p structure as: [Page 7] [Depth 6] [Paragraph] [Pos: 472,215]:
# Node h3 structure as: [Page 7] [Depth 5] [Paragraph] [Pos: 472,254] [H3]:
# Node p structure as: [Page 7] [Depth 6] [Paragraph] [Pos: 472,266]:
# Node h3 structure as: [Page 7] [Depth 4] [Paragraph] [Pos: 472,332] [H3]:
# Node h3 structure as: [Page 7] [Depth 5] [Paragraph] [Pos: 472,353] [H3]:
# Node p structure as: [Page 7] [Depth 6] [Paragraph] [Pos: 472,366]:
# Node p structure as: [Page 7] [Depth 6] [Paragraph] [Pos: 550,447]:
# Node figure structure as: [Page 7] [Depth 6] [Figure] [Pos: 483,478]:
# Node img structure as: [Depth 7]:
# Node figure structure as: [Page 7] [Depth 6] [Figure] [Pos: 662,177]:
# Node img structure as: [Depth 7]:
# Node footer structure as: [Page 7] [Depth 6] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 7] [Depth 6] [Page_footer] [Pos: 831,663]:
# Node figure structure as: [Page 8] [Depth 6] [Figure] [Pos: 19,0]:
# Node img structure as: [Depth 7]:
# Node h3 structure as: [Page 8] [Depth 1] [Paragraph] [Pos: 48,508] [H3]:
# Node p structure as: [Page 8] [Depth 2] [Paragraph] [Pos: 492,21]:
# Node figure structure as: [Page 8] [Depth 2] [Figure] [Pos: 474,24]:
# Node img structure as: [Depth 3]:
# Node figure structure as: [Page 8] [Depth 2] [Figure] [Pos: 459,208]:
# Node img structure as: [Depth 3]:
# Node figure structure as: [Page 8] [Depth 2] [Figure] [Pos: 664,10]:
# Node img structure as: [Depth 3]:
# Node figure structure as: [Page 8] [Depth 2] [Figure] [Pos: 664,288]:
# Node img structure as: [Depth 3]:
# Node figure structure as: [Page 8] [Depth 2] [Figure] [Pos: 458,444]:
# Node img structure as: [Depth 3]:
# Node h3 structure as: [Page 9] [Depth 2] [Paragraph] [Pos: 28,28] [H3]:
# Node p structure as: [Page 9] [Depth 3] [Paragraph] [Pos: 472,32]:
# Node h3 structure as: [Page 9] [Depth 3] [Paragraph] [Pos: 666,33] [H3]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 33,102]:
# Node figure structure as: [Page 9] [Depth 4] [Figure] [Pos: 30,152]:
# Node img structure as: [Depth 5]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 33,382]:
# Node h2 structure as: [Page 9] [Depth 3] [Paragraph] [Pos: 34,454] [H2]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 33,465]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 31,477]:
# Node h3 structure as: [Page 9] [Depth 3] [Paragraph] [Pos: 227,452] [H3]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 226,465]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 470,46]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 472,215]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 470,304]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 664,44]:
# Node h2 structure as: [Page 9] [Depth 3] [Paragraph] [Pos: 666,202] [H2]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 664,226]:
# Node h3 structure as: [Page 9] [Depth 3] [Paragraph] [Pos: 666,371] [H3]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 664,382]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 470,496]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 480,530]:
# Node p structure as: [Page 9] [Depth 4] [Paragraph] [Pos: 482,625]:
# Node figure structure as: [Page 9] [Depth 4] [Figure] [Pos: 725,518]:
# Node img structure as: [Depth 5]:
# Node footer structure as: [Page 9] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 9] [Depth 4] [Page_footer] [Pos: 831,663]:
# Node h2 structure as: [Page 10] [Depth 2] [Paragraph] [Pos: 22,22] [H2]:
# Node p structure as: [Page 10] [Depth 3] [Paragraph] [Pos: 35,104]:
# Node p structure as: [Page 10] [Depth 3] [Paragraph] [Pos: 62,148]:
# Node figure structure as: [Page 10] [Depth 3] [Figure] [Pos: 30,195]:
# Node img structure as: [Depth 4]:
# Node h1 structure as: [Page 10] [Depth 3] [Paragraph] [Pos: 472,33] [H1]:
# Node p structure as: [Page 10] [Depth 4] [Paragraph] [Pos: 471,46]:
# Node p structure as: [Page 10] [Depth 4] [Paragraph] [Pos: 471,58]:
# Node figure structure as: [Page 10] [Depth 4] [Figure] [Pos: 470,172]:
# Node img structure as: [Depth 5]:
# Node p structure as: [Page 10] [Depth 4] [Paragraph] [Pos: 484,316]:
# Node p structure as: [Page 10] [Depth 4] [Paragraph] [Pos: 484,446]:
# Node figure structure as: [Page 10] [Depth 4] [Figure] [Pos: 656,30]:
# Node img structure as: [Depth 5]:
# Node h2 structure as: [Page 10] [Depth 3] [Paragraph] [Pos: 674,218] [H2]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node h3 structure as: [Page 10] [Depth 3] [Paragraph] [Pos: 672,474] [H3]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node footer structure as: [Page 10] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 10] [Depth 4] [Page_footer] [Pos: 830,663]:
# Node h4 structure as: [Page 11] [Depth 3] [Paragraph] [Pos: 32,32] [H4]:
# Node p structure as: [Page 11] [Depth 4] [Paragraph] [Pos: 33,46]:
# Node p structure as: [Page 11] [Depth 4] [Paragraph] [Pos: 55,233]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node figure structure as: [Page 11] [Depth 4] [Figure] [Pos: 466,28]:
# Node img structure as: [Depth 5]:
# Node p structure as: [Page 11] [Depth 4] [Paragraph] [Pos: 475,209]:
# Node p structure as: [Page 11] [Depth 4] [Paragraph] [Pos: 496,386]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node footer structure as: [Page 11] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 11] [Depth 4] [Page_footer] [Pos: 830,663]:
# Node p structure as: [Page 11] [Depth 4] [Paragraph] [Pos: 674,356]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node p structure as: [Page 11] [Depth 4] [Paragraph] [Pos: 667,265]:
# Node h2 structure as: [Page 12] [Depth 3] [Paragraph] [Pos: 32,32] [H2]:
# Node p structure as: [Page 12] [Depth 4] [Paragraph] [Pos: 227,32]:
# Node p structure as: [Page 12] [Depth 4] [Paragraph] [Pos: 32,46]:
# Node figure structure as: [Page 12] [Depth 4] [Figure] [Pos: 31,132]:
# Node img structure as: [Depth 5]:
# Node h4 structure as: [Page 12] [Depth 4] [Paragraph] [Pos: 46,321] [H4]:
# Node ul structure as: [Depth 5] [Merged_paragraph]:
# Node h2 structure as: [Page 12] [Depth 4] [Paragraph] [Pos: 46,499] [H2]:
# Node h3 structure as: [Page 12] [Depth 4] [Paragraph] [Pos: 48,514] [H3]:
# Node ul structure as: [Depth 5] [Merged_paragraph]:
# Node h3 structure as: [Page 12] [Depth 3] [Paragraph] [Pos: 471,278] [H3]:
# Node p structure as: [Page 12] [Depth 4] [Paragraph] [Pos: 472,292]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node h2 structure as: [Page 12] [Depth 3] [Paragraph] [Pos: 472,494] [H2]:
# Node p structure as: [Page 12] [Depth 4] [Paragraph] [Pos: 472,508]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node h2 structure as: [Page 13] [Depth 3] [Paragraph] [Pos: 33,33] [H2]:
# Node h3 structure as: [Page 13] [Depth 4] [Paragraph] [Pos: 32,46] [H3]:
# Node p structure as: [Page 13] [Depth 5] [Paragraph] [Pos: 31,58]:
# Node p structure as: [Page 13] [Depth 5] [Paragraph] [Pos: 32,163]:
# Node figure structure as: [Page 13] [Depth 5] [Figure] [Pos: 28,218]:
# Node img structure as: [Depth 6]:
# Node p structure as: [Page 13] [Depth 5] [Paragraph] [Pos: 225,110]:
# Node figure structure as: [Page 13] [Depth 5] [Figure] [Pos: 468,31]:
# Node img structure as: [Depth 6]:
# Node h3 structure as: [Page 13] [Depth 4] [Paragraph] [Pos: 486,307] [H3]:
# Node ul structure as: [Depth 5] [Merged_paragraph]:
# Node h3 structure as: [Page 13] [Depth 4] [Paragraph] [Pos: 486,454] [H3]:
# Node ul structure as: [Depth 5] [Merged_paragraph]:
# Node figure structure as: [Page 13] [Depth 5] [Figure] [Pos: 640,290]:
# Node img structure as: [Depth 6]:
# Node h4 structure as: [Page 13] [Depth 4] [Paragraph] [Pos: 656,452] [H4]:
# Node ul structure as: [Depth 5] [Merged_paragraph]:
# Node footer structure as: [Page 13] [Depth 5] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 13] [Depth 5] [Page_footer] [Pos: 830,663]:
# Node h2 structure as: [Page 14] [Depth 2] [Paragraph] [Pos: 31,31] [H2]:
# Node p structure as: [Page 14] [Depth 3] [Paragraph] [Pos: 33,112]:
# Node figure structure as: [Page 14] [Depth 3] [Figure] [Pos: 30,177]:
# Node img structure as: [Depth 4]:
# Node figure structure as: [Page 14] [Depth 3] [Figure] [Pos: 644,30]:
# Node img structure as: [Depth 4]:
# Node h2 structure as: [Page 14] [Depth 3] [Paragraph] [Pos: 647,231] [H2]:
# Node p structure as: [Page 14] [Depth 4] [Paragraph] [Pos: 646,244]:
# Node h3 structure as: [Page 14] [Depth 3] [Paragraph] [Pos: 647,360] [H3]:
# Node p structure as: [Page 14] [Depth 4] [Paragraph] [Pos: 646,373]:
# Node footer structure as: [Page 14] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 14] [Depth 4] [Page_footer] [Pos: 830,663]:
# Node h2 structure as: [Page 15] [Depth 3] [Paragraph] [Pos: 32,32] [H2]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 31,58]:
# Node h2 structure as: [Page 15] [Depth 3] [Paragraph] [Pos: 32,280] [H2]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 31,294]:
# Node figure structure as: [Page 15] [Depth 4] [Figure] [Pos: 26,396]:
# Node img structure as: [Depth 5]:
# Node figure structure as: [Page 15] [Depth 4] [Figure] [Pos: 178,26]:
# Node img structure as: [Depth 5]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 262,242]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 225,280]:
# Node h3 structure as: [Page 15] [Depth 3] [Paragraph] [Pos: 472,32] [H3]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 470,46]:
# Node figure structure as: [Page 15] [Depth 4] [Figure] [Pos: 556,172]:
# Node img structure as: [Depth 5]:
# Node h3 structure as: [Page 15] [Depth 3] [Paragraph] [Pos: 536,216] [H3]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 500,226]:
# Node figure structure as: [Page 15] [Depth 4] [Figure] [Pos: 550,376]:
# Node img structure as: [Depth 5]:
# Node h3 structure as: [Page 15] [Depth 3] [Paragraph] [Pos: 546,422] [H3]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 496,440]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 660,31]:
# Node figure structure as: [Page 15] [Depth 4] [Figure] [Pos: 728,170]:
# Node img structure as: [Depth 5]:
# Node h3 structure as: [Page 15] [Depth 3] [Paragraph] [Pos: 682,216] [H3]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 669,224]:
# Node figure structure as: [Page 15] [Depth 4] [Figure] [Pos: 730,377]:
# Node img structure as: [Depth 5]:
# Node p structure as: [Page 15] [Depth 4] [Paragraph] [Pos: 672,427]:
# Node footer structure as: [Page 15] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 15] [Depth 4] [Page_footer] [Pos: 830,663]:
# Node figure structure as: [Page 16] [Depth 4] [Figure] [Pos: 16,0]:
# Node img structure as: [Depth 5]:
# Node h2 structure as: [Page 16] [Depth 1] [Paragraph] [Pos: 32,508] [H2]:
# Node p structure as: [Page 16] [Depth 2] [Paragraph] [Pos: 476,20]:
# Node figure structure as: [Page 16] [Depth 2] [Figure] [Pos: 665,6]:
# Node img structure as: [Depth 3]:
# Node figure structure as: [Page 16] [Depth 2] [Figure] [Pos: 454,308]:
# Node img structure as: [Depth 3]:
# Node h3 structure as: [Page 17] [Depth 2] [Paragraph] [Pos: 22,24] [H3]:
# Node h3 structure as: [Page 17] [Depth 3] [Paragraph] [Pos: 472,32] [H3]:
# Node p structure as: [Page 17] [Depth 4] [Paragraph] [Pos: 470,44]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node figure structure as: [Page 17] [Depth 4] [Figure] [Pos: 28,102]:
# Node img structure as: [Depth 5]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node figure structure as: [Page 17] [Depth 4] [Figure] [Pos: 464,222]:
# Node img structure as: [Depth 5]:
# Node h3 structure as: [Page 17] [Depth 3] [Paragraph] [Pos: 472,479] [H3]:
# Node p structure as: [Page 17] [Depth 4] [Paragraph] [Pos: 470,490]:
# Node p structure as: [Page 17] [Depth 4] [Paragraph] [Pos: 676,490]:
# Node footer structure as: [Page 17] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 17] [Depth 4] [Page_footer] [Pos: 830,663]:
# Node figure structure as: [Page 18] [Depth 4] [Figure] [Pos: 26,26]:
# Node img structure as: [Depth 5]:
# Node h2 structure as: [Page 18] [Depth 3] [Paragraph] [Pos: 32,481] [H2]:
# Node p structure as: [Page 18] [Depth 4] [Paragraph] [Pos: 31,494]:
# Node p structure as: [Page 18] [Depth 4] [Paragraph] [Pos: 225,479]:
# Node p structure as: [Page 18] [Depth 4] [Paragraph] [Pos: 470,31]:
# Node p structure as: [Page 18] [Depth 4] [Paragraph] [Pos: 471,227]:
# Node figure structure as: [Page 18] [Depth 4] [Figure] [Pos: 418,296]:
# Node img structure as: [Depth 5]:
# Node p structure as: [Page 18] [Depth 4] [Paragraph] [Pos: 502,535]:
# Node p structure as: [Page 18] [Depth 4] [Paragraph] [Pos: 664,31]:
# Node ul structure as: [Depth 4] [Merged_paragraph]:
# Node footer structure as: [Page 18] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 18] [Depth 4] [Page_footer] [Pos: 830,663]:
# Node h2 structure as: [Page 19] [Depth 2] [Paragraph] [Pos: 22,24] [H2]:
# Node figure structure as: [Page 19] [Depth 3] [Figure] [Pos: 35,102]:
# Node img structure as: [Depth 4]:
# Node p structure as: [Page 19] [Depth 3] [Paragraph] [Pos: 70,112]:
# Node figure structure as: [Page 19] [Depth 3] [Figure] [Pos: 30,161]:
# Node img structure as: [Depth 4]:
# Node figure structure as: [Page 19] [Depth 3] [Figure] [Pos: 470,30]:
# Node img structure as: [Depth 4]:
# Node h1 structure as: [Page 19] [Depth 3] [Paragraph] [Pos: 472,245] [H1]:
# Node h3 structure as: [Page 19] [Depth 4] [Paragraph] [Pos: 472,258] [H3]:
# Node h5 structure as: [Page 19] [Depth 4] [Paragraph] [Pos: 473,271] [H5]:
# Node h2 structure as: [Page 19] [Depth 4] [Paragraph] [Pos: 472,284] [H2]:
# Node p structure as: [Page 19] [Depth 5] [Paragraph] [Pos: 471,298]:
# Node h2 structure as: [Page 19] [Depth 3] [Paragraph] [Pos: 471,387] [H2]:
# Node h2 structure as: [Page 19] [Depth 4] [Paragraph] [Pos: 471,402] [H2]:
# Node h1 structure as: [Page 19] [Depth 4] [Paragraph] [Pos: 472,414] [H1]:
# Node p structure as: [Page 19] [Depth 5] [Paragraph] [Pos: 470,426]:
# Node h1 structure as: [Page 19] [Depth 3] [Paragraph] [Pos: 472,544] [H1]:
# Node h2 structure as: [Page 19] [Depth 4] [Paragraph] [Pos: 472,571] [H2]:
# Node p structure as: [Page 19] [Depth 5] [Paragraph] [Pos: 471,582]:
# Node h3 structure as: [Page 19] [Depth 3] [Paragraph] [Pos: 665,245] [H3]:
# Node h2 structure as: [Page 19] [Depth 4] [Paragraph] [Pos: 666,258] [H2]:
# Node p structure as: [Page 19] [Depth 5] [Paragraph] [Pos: 664,270]:
# Node h3 structure as: [Page 19] [Depth 3] [Paragraph] [Pos: 665,388] [H3]:
# Node h2 structure as: [Page 19] [Depth 4] [Paragraph] [Pos: 665,402] [H2]:
# Node p structure as: [Page 19] [Depth 5] [Paragraph] [Pos: 665,414]:
# Node footer structure as: [Page 19] [Depth 5] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 19] [Depth 5] [Page_footer] [Pos: 830,663]:
# Node h5 structure as: [Page 20] [Depth 3] [Paragraph] [Pos: 32,32] [H5]:
# Node h3 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 32,46] [H3]:
# Node p structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 33,60]:
# Node h3 structure as: [Page 20] [Depth 3] [Paragraph] [Pos: 32,124] [H3]:
# Node h2 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 33,138] [H2]:
# Node p structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 30,148]:
# Node h3 structure as: [Page 20] [Depth 3] [Paragraph] [Pos: 32,292] [H3]:
# Node h3 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 32,306] [H3]:
# Node p structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 32,319]:
# Node figure structure as: [Page 20] [Depth 5] [Figure] [Pos: 28,380]:
# Node img structure as: [Depth 6]:
# Node figure structure as: [Page 20] [Depth 5] [Figure] [Pos: 214,28]:
# Node img structure as: [Depth 6]:
# Node h2 structure as: [Page 20] [Depth 3] [Paragraph] [Pos: 472,328] [H2]:
# Node h5 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 472,350] [H5]:
# Node h3 structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 471,362] [H3]:
# Node table structure as: [Page 20] [Depth 6] [Table] [Pos: 471,375]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node h2 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 471,427] [H2]:
# Node h2 structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 471,440] [H2]:
# Node table structure as: [Page 20] [Depth 6] [Table] [Pos: 472,452]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node h3 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 471,504] [H3]:
# Node h2 structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 472,518] [H2]:
# Node table structure as: [Page 20] [Depth 6] [Table] [Pos: 472,531]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node h4 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 471,583] [H4]:
# Node h4 structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 472,596] [H4]:
# Node table structure as: [Page 20] [Depth 6] [Table] [Pos: 472,608]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node h4 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 665,350] [H4]:
# Node h6 structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 666,362] [H6]:
# Node table structure as: [Page 20] [Depth 6] [Table] [Pos: 666,376]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node h2 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 665,427] [H2]:
# Node h5 structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 666,441] [H5]:
# Node p structure as: [Page 20] [Depth 6] [Paragraph] [Pos: 666,454]:
# Node p structure as: [Page 20] [Depth 6] [Paragraph] [Pos: 667,468]:
# Node h4 structure as: [Page 20] [Depth 4] [Paragraph] [Pos: 666,494] [H4]:
# Node h2 structure as: [Page 20] [Depth 5] [Paragraph] [Pos: 666,506] [H2]:
# Node table structure as: [Page 20] [Depth 6] [Table] [Pos: 666,519]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node tr structure as: [Depth 7]:
# Node td structure as: [Depth 8]:
# Node td structure as: [Depth 8]:
# Node p structure as: [Page 20] [Depth 6] [Paragraph] [Pos: 665,569]:
# Node footer structure as: [Page 20] [Depth 6] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 20] [Depth 6] [Page_footer] [Pos: 830,663]:
# Node h1 structure as: [Page 21] [Depth 2] [Paragraph] [Pos: 28,34] [H1]:
# Node h2 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 32,106] [H2]:
# Node h3 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 162,106] [H3]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 162,122] [H3]:
# Node h2 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 33,122] [H2]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 162,134]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 162,145]:
# Node h2 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 32,144] [H2]:
# Node h4 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 162,168] [H4]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 33,172] [H3]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 32,184]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 162,184] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 162,198]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 32,199] [H3]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 33,222]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 162,213] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 162,226]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 32,240] [H4]:
# Node h2 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 162,247] [H2]:
# Node p structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 32,251]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 32,267] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 32,278]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 32,296] [H3]:
# Node h4 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 161,296] [H4]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 33,312] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 33,324]:
# Node h4 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 292,106] [H4]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 292,122] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,134]:
# Node h2 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 292,150] [H2]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,162]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 290,178] [H3]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,202]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 292,218] [H3]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,231]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,246]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,256]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,274]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,286]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,301]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 292,314]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 162,325]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 162,336]:
# Node h4 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 471,106] [H4]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 472,123] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 472,136]:
# Node h2 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 601,148] [H2]:
# Node h5 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 470,156] [H5]:
# Node h5 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 602,176] [H5]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,174]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 601,192]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,202]:
# Node h4 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 601,215] [H4]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,218] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,230]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 601,231] [H3]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 601,244]:
# Node h5 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,246] [H5]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,258]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 601,258]:
# Node h5 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 471,262] [H5]:
# Node h5 structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 472,272] [H5]:
# Node h2 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 601,274] [H2]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,287]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 601,303] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 601,316]:
# Node h2 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 730,308] [H2]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,335] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,359]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,370]:
# Node h5 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,384] [H5]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,398]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,410]:
# Node h2 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 730,432] [H2]:
# Node p structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 732,449]:
# Node p structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 728,460]:
# Node h2 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 730,495] [H2]:
# Node p structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,522]:
# Node p structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,536]:
# Node footer structure as: [Page 21] [Depth 4] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 21] [Depth 4] [Page_footer] [Pos: 830,663]:
# Node h3 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 601,106] [H3]:
# Node h2 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,106] [H2]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,118]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 601,134] [H4]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 732,134] [H4]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 730,146]:
# Node h2 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,162] [H2]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 162,263] [H3]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 162,274]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 601,287]:
# Node figure structure as: [Page 21] [Depth 5] [Figure] [Pos: 26,358]:
# Node img structure as: [Depth 6]:
# Node h2 structure as: [Page 21] [Depth 3] [Paragraph] [Pos: 472,217] [H2]:
# Node h3 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 471,233] [H3]:
# Node p structure as: [Page 21] [Depth 5] [Paragraph] [Pos: 471,244]:
# Node h4 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,274] [H4]:
# Node h1 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 730,190] [H1]:
# Node h2 structure as: [Page 21] [Depth 4] [Paragraph] [Pos: 472,196] [H2]:
# Node figure structure as: [Page 22] [Depth 5] [Figure] [Pos: 496,30]:
# Node img structure as: [Depth 6]:
# Node figure structure as: [Page 22] [Depth 5] [Figure] [Pos: 26,22]:
# Node img structure as: [Depth 6]:
# Node h2 structure as: [Page 22] [Depth 3] [Paragraph] [Pos: 33,420] [H2]:
# Node h4 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 33,436] [H4]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 33,449]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 33,464] [H2]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 30,476]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 32,504] [H2]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 33,528]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 161,528]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 162,540]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 32,542] [H3]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 160,568]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 161,556]:
# Node h4 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 32,582] [H4]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 32,594]:
# Node h4 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 161,596] [H4]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 32,610] [H3]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 159,607]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 290,420]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 162,420] [H3]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 159,431]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 290,432]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 290,449] [H3]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 288,458]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 161,459] [H2]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 162,472]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 161,488] [H3]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 161,500]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 162,517]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 290,528] [H3]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 288,540]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 290,568] [H2]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 288,580]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 290,608] [H3]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 290,620]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 290,632]:
# Node figure structure as: [Page 22] [Depth 5] [Figure] [Pos: 494,209]:
# Node img structure as: [Depth 6]:
# Node h2 structure as: [Page 22] [Depth 3] [Paragraph] [Pos: 600,420] [H2]:
# Node h3 structure as: [Page 22] [Depth 3] [Paragraph] [Pos: 728,420] [H3]:
# Node h4 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 728,434] [H4]:
# Node h4 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 600,436] [H4]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 601,450]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 472,447]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 726,447]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 601,465] [H3]:
# Node h4 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 728,476] [H4]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 601,477]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 730,488]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 600,492] [H2]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 728,504] [H2]:
# Node h3 structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 730,517] [H3]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 601,520] [H2]:
# Node h3 structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 601,533] [H3]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 601,549] [H2]:
# Node h5 structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 601,562] [H5]:
# Node h3 structure as: [Page 22] [Depth 3] [Paragraph] [Pos: 470,546] [H3]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 600,576] [H2]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 601,590]:
# Node footer structure as: [Page 22] [Depth 5] [Page_footer] [Pos: 34,663]:
# Node footer structure as: [Page 22] [Depth 5] [Page_footer] [Pos: 830,663]:
# Node h4 structure as: [Page 22] [Depth 3] [Paragraph] [Pos: 471,470] [H4]:
# Node h2 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 472,485] [H2]:
# Node h3 structure as: [Page 22] [Depth 3] [Paragraph] [Pos: 471,508] [H3]:
# Node h4 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 472,522] [H4]:
# Node h5 structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 32,566] [H5]:
# Node h3 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 472,584] [H3]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 472,598]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 33,623]:
# Node h3 structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 601,506] [H3]:
# Node h4 structure as: [Page 22] [Depth 4] [Paragraph] [Pos: 290,488] [H4]:
# Node p structure as: [Page 22] [Depth 5] [Paragraph] [Pos: 288,498]:
# Node h3 structure as: [Page 22] [Depth 3] [Paragraph] [Pos: 470,418] [H3]:
# Node h2 structure as: [Page 23] [Depth 2] [Paragraph] [Pos: 21,22] [H2]:
# Node p structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 33,102]:
# Node h3 structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 32,168] [H3]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 226,166]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 31,179]:
# Node figure structure as: [Page 23] [Depth 4] [Figure] [Pos: 28,258]:
# Node img structure as: [Depth 5]:
# Node figure structure as: [Page 23] [Depth 4] [Figure] [Pos: 470,30]:
# Node img structure as: [Depth 5]:
# Node h2 structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 471,220] [H2]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 471,233]:
# Node h2 structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 472,336] [H2]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 471,350]:
# Node h3 structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 472,440] [H3]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 471,454]:
# Node h3 structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 471,533] [H3]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 471,546]:
# Node h3 structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 689,220] [H3]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 688,230]:
# Node h4 structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 690,336] [H4]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 688,348]:
# Node h3 structure as: [Page 23] [Depth 3] [Paragraph] [Pos: 690,454] [H3]:
# Node p structure as: [Page 23] [Depth 4] [Paragraph] [Pos: 687,467]:
# Node footer structure as: [Page 23] [Depth 4] [Page_footer] [Pos: 33,663]:
# Node footer structure as: [Page 23] [Depth 4] [Page_footer] [Pos: 830,663]:
# Node figure structure as: [Page 24] [Depth 4] [Figure] [Pos: 13,12]:
# Node img structure as: [Depth 5]:
# Node h1 structure as: [Page 24] [Depth 1] [Paragraph] [Pos: 37,477] [H1]:
# Node figure structure as: [Page 24] [Depth 2] [Figure] [Pos: 37,508]:
# Node img structure as: [Depth 3]:
# Node p structure as: [Page 24] [Depth 2] [Paragraph] [Pos: 54,510]:
# Node figure structure as: [Page 24] [Depth 2] [Figure] [Pos: 36,538]:
# Node img structure as: [Depth 3]:
# Node p structure as: [Page 24] [Depth 2] [Paragraph] [Pos: 36,538]:
# Node p structure as: [Page 24] [Depth 2] [Paragraph] [Pos: 35,567]:
# Node p structure as: [Page 24] [Depth 2] [Paragraph] [Pos: 37,598]:
# Node p structure as: [Page 24] [Depth 2] [Paragraph] [Pos: 52,628]:
# Node figure structure as: [Page 24] [Depth 2] [Figure] [Pos: 36,625]:
# Node img structure as: [Depth 3]:
# Node figure structure as: [Page 24] [Depth 2] [Figure] [Pos: 811,456]:
# Node img structure as: [Depth 3]:
# Node p structure as: [Page 24] [Depth 2] [Paragraph] [Pos: 811,512]:
# Node figure structure as: [Page 24] [Depth 2] [Figure] [Pos: 751,587]:
# Node img structure as: [Depth 3]:
# Node p structure as: [Page 24] [Depth 1] [Paragraph] [Pos: 670,645]:
